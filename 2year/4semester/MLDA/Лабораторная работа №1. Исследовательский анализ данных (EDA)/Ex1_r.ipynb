# %% [markdown]
# # Инициализация проекта

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import warnings

# %%
data= pd.read_csv('../datasets/moldova_cars_task.csv')

# %% [markdown]
# # Исследование исходных данных

# %% [markdown]
# <font size=4>
# Датасет содержит следующие поля:
#
# - `Make` — марка
# - `Model` — модель
# - `Year` — год выпуска
# - `Style` — тип кузова
# - `Distance` — пробег
# - `Engine_capacity(cm3)` — объём двигателя в кубических сантиметрах
# - `Fuel_type` — тип топлива
# - `Transmission` — коробка передач
# - `Price(euro)` — цена автомобиля в евро
# </font>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41007 entries, 0 to 41006
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Make                  41007 non-null  object
#  1   Model                 40671 non-null  object
#  2   Year                  40771 non-null  float64
#  3   Style                 40938 non-null  object
#  4   Distance              40889 non-null  float64
#  5   Engine_capacity(cm3)  41007 non-null  float64
#  6   Fuel_type             41007 non-null  object
#  7   Transmission          40779 non-null  object
#  8   Price(euro)           41007 non-null  float64
# dtypes: float64(4), object(5)
# memory usage: 2.8+ MB

# %%
data.head(20)
# Out:
#           Make          Model    Year      Style  Distance  \
# 0       Toyota          Prius  2011.0  Hatchback  195000.0
# 1      Renault   Grand Scenic  2014.0  Universal  135000.0
# 2   Volkswagen           Golf  1998.0  Hatchback       1.0
# 3      Renault         Laguna  2012.0  Universal  110000.0
# 4         Opel          Astra  2006.0  Universal  200000.0
# 5     Mercedes           Vito  2000.0   Microvan  300000.0
# 6   Volkswagen         Passat  2010.0  Universal  290000.0
# 7   Volkswagen        Touareg  2010.0        SUV  220000.0
# 8     Mercedes  Series (W124)  1991.0      Sedan  240000.0
# 9          BMW       5 Series  2004.0      Sedan  325000.0
# 10    Mercedes        E Class  2010.0      Sedan  210000.0
# 11    Mercedes      CLS Class  2006.0      Coupe  300000.0
# 12         KIA            Rio  2005.0  Universal      23.0
# 13         BMW       7 Series  1998.0      Sedan  285000.0
# 14  Volkswagen           Golf  2007.0  Universal  238371.0
# 15  Volkswagen      Golf Plus  2010.0  Hatchback  150000.0
# 16       Volvo           XC60  2012.0  Crossover  180000.0
# 17      Nissan        Qashqai  2011.0  Crossover  251000.0
# 18     Hyundai         Matrix  2005.0  Universal  383000.0
# 19        Audi             A3  2009.0  Hatchback  248000.0
#
#     Engine_capacity(cm3)     Fuel_type Transmission  Price(euro)
# 0                 1800.0        Hybrid    Automatic       7750.0
# 1                 1500.0        Diesel       Manual       8550.0
# 2                 1400.0        Petrol       Manual       2200.0
# 3                 1500.0        Diesel       Manual       6550.0
# 4                 1600.0  Metan/Propan       Manual       4100.0
# 5                 2200.0        Diesel       Manual       3490.0
# 6                 1390.0        Petrol       Manual       5600.0
# 7                 2400.0        Diesel    Automatic      17000.0
# 8                 2300.0        Petrol       Manual       2850.0
# 9                  300.0        Diesel       Manual       3400.0
# 10                2200.0        Diesel    Automatic      11400.0
# 11                3200.0        Diesel    Automatic      11800.0
# 12                1300.0        Petrol       Manual       1550.0
# 13                3500.0        Petrol       Manual       3990.0
# 14                1400.0        Petrol    Automatic       5000.0
# 15                1200.0        Petrol       Manual       5500.0
# 16                2400.0        Diesel    Automatic      15900.0
# 17                1500.0        Diesel       Manual       8300.0
# 18                1500.0        Diesel       Manual       3200.0
# 19                2000.0        Diesel    Automatic       9299.0

# %% [markdown]
# <font size=4><b>Получили следующую характеристику исходных данных:</b>
#
# - в столбце 'Distance' есть подозрительно низкие значения (1.0 и 23.0), которые могут быть ошибками;
# - в столбце 'Engine_capacity(cm3)' значение 300.0 для BMW 5 Series выглядит аномально низким;
# - пропущенных значений в данных в первых 20 строках не наблюдается
# - тип данных столбцов 'Year', 'Distance', 'Engine_capacity(cm3)' и 'Price(euro)' стоит перевести в целочисленный
# </font>

# %% [markdown]
# <font size=4>Столбцы с неподходящими типами данных:
#
# - изменение типа данных столбца 'Year' с float на int;
# - изменение типа данных столбца 'Distance' с float на int;
# - изменение типа данных столбца 'Engine_capacity(cm3)' с float на int;
# - изменение типа данных столбца 'Price(euro)' с float на int;
# </font>

# %% [markdown]
# # Выводы и дальнейшие шаги</font>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41007 entries, 0 to 41006
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Make                  41007 non-null  object
#  1   Model                 40671 non-null  object
#  2   Year                  40771 non-null  float64
#  3   Style                 40938 non-null  object
#  4   Distance              40889 non-null  float64
#  5   Engine_capacity(cm3)  41007 non-null  float64
#  6   Fuel_type             41007 non-null  object
#  7   Transmission          40779 non-null  object
#  8   Price(euro)           41007 non-null  float64
# dtypes: float64(4), object(5)
# memory usage: 2.8+ MB

# %%
data.describe()
# Out:
#                Year      Distance  Engine_capacity(cm3)   Price(euro)
# count  40771.000000  4.088900e+04          41007.000000  4.100700e+04
# mean    2007.979152  4.571171e+05           1853.856732  9.727109e+03
# std        8.246369  4.457945e+06            700.364532  5.043926e+04
# min     1900.000000  0.000000e+00              0.000000  1.000000e+00
# 25%     2004.000000  8.700000e+04           1500.000000  3.500000e+03
# 50%     2009.000000  1.680000e+05           1800.000000  6.600000e+03
# 75%     2014.000000  2.300000e+05           2000.000000  1.215000e+04
# max     2021.000000  1.000000e+08           9999.000000  1.000000e+07

# %% [markdown]
# <b>Вывод:</b>
#
# - Год выпуска автомобилей варьируется от 1900 до 2021, средний год выпуска — 2007
# - Пробег автомобилей имеет значительный разброс: минимальное значение — 0 км, максимальное — 100 млн км, что может указывать на выбросы или ошибки в данных
# - Объем двигателя в среднем составляет 1900 см³, но есть аномально низкое значение (300.0 для BMW 5 Series).
# - Цены на автомобили варьируются от 1550 до 17000 евро, средняя цена — 7788.95 евро.

# %% [markdown]
# ## Обработка пропущенных значений

# %%
(data.isna().sum()/data.shape[0]*100).sort_values(ascending=False)
# Out:
# Model                   0.819372
# Year                    0.575511
# Transmission            0.556003
# Distance                0.287756
# Style                   0.168264
# Make                    0.000000
# Engine_capacity(cm3)    0.000000
# Fuel_type               0.000000
# Price(euro)             0.000000
# dtype: float64

# %% [markdown]
# <font size=4><b>Недостающее значение данных в следующих столбцах:</b>
#
# - Model (0.82%)
# - Year (0.58%)
# - Transmission (0.56%)
# - Distance (0.29%)
# - Style (0.17%)</font>
#
# <font size=4><b>Предположения для заполнения пропущенного значения:</b>
#
# - Model: Заполнить пропущенные значения на основе наиболее часто встречающихся моделей для каждого производителя
# - Year: Заполнить пропущенные значения медианным годом выпуска для каждой модели или производителя.
# - Transmission: Заполнить пропуски наиболее часто встречающимся типом трансмиссии для каждой модели или производителя.
# - Distance: Заполнить пропущенные значения медианным пробегом для автомобилей с аналогичными характеристиками.
# - Style: Заполнить пропущенные значения наиболее часто встречающимся стилем кузова для каждой модели или производителя.

# %%
f = lambda x: x.mode().iat[0] if x.notna().any() else np.nan
group_model = data.groupby('Make')['Model'].transform(f)
data['Model'] = data['Model'].fillna(group_model)
(data.isna().sum()/data.shape[0]*100).sort_values(ascending=False)
# Out:
# Year                    0.575511
# Transmission            0.556003
# Distance                0.287756
# Style                   0.168264
# Make                    0.000000
# Model                   0.000000
# Engine_capacity(cm3)    0.000000
# Fuel_type               0.000000
# Price(euro)             0.000000
# dtype: float64

# %%
group_year = data.groupby('Model')['Year'].transform('median')
data['Year'] = data['Year'].fillna(group_year)
(data.isna().sum()/data.shape[0]*100).sort_values(ascending=False)
# Out:
# Transmission            0.556003
# Distance                0.287756
# Style                   0.168264
# Make                    0.000000
# Year                    0.000000
# Model                   0.000000
# Engine_capacity(cm3)    0.000000
# Fuel_type               0.000000
# Price(euro)             0.000000
# dtype: float64

# %%
group_transmission = data.groupby('Model')['Transmission'].transform(f)
data ['Transmission'] = data ['Transmission'].fillna(group_transmission)
if data['Transmission'].isna().any():
    group_transmission_make = data.groupby('Make')['Transmission'].transform(f)
    data['Transmission'] = data['Transmission'].fillna(group_transmission_make)

(data.isna().sum()/data.shape[0]*100).sort_values(ascending=False)
# Out:
# Distance                0.287756
# Style                   0.168264
# Make                    0.000000
# Year                    0.000000
# Model                   0.000000
# Engine_capacity(cm3)    0.000000
# Fuel_type               0.000000
# Transmission            0.000000
# Price(euro)             0.000000
# dtype: float64

# %%
group_distance = data.groupby('Model')['Distance'].transform('median')
data['Distance'] = data['Distance'].fillna(group_distance)
(data.isna().sum()/data.shape[0]*100).sort_values(ascending=False)
# Out:
# Style                   0.168264
# Make                    0.000000
# Model                   0.000000
# Year                    0.000000
# Distance                0.000000
# Engine_capacity(cm3)    0.000000
# Fuel_type               0.000000
# Transmission            0.000000
# Price(euro)             0.000000
# dtype: float64

# %%
group_style = data.groupby('Model')['Style'].transform(f)
data['Style'] = data['Style'].fillna(group_style)
(data.isna().sum()/data.shape[0]*100).sort_values(ascending=False)
# Out:
# Make                    0.0
# Model                   0.0
# Year                    0.0
# Style                   0.0
# Distance                0.0
# Engine_capacity(cm3)    0.0
# Fuel_type               0.0
# Transmission            0.0
# Price(euro)             0.0
# dtype: float64

# %%
data
# Out:
#              Make         Model    Year      Style  Distance  \
# 0          Toyota         Prius  2011.0  Hatchback  195000.0
# 1         Renault  Grand Scenic  2014.0  Universal  135000.0
# 2      Volkswagen          Golf  1998.0  Hatchback       1.0
# 3         Renault        Laguna  2012.0  Universal  110000.0
# 4            Opel         Astra  2006.0  Universal  200000.0
# ...           ...           ...     ...        ...       ...
# 41002       Dacia         Logan  2015.0  Universal   89000.0
# 41003     Renault         Modus  2009.0  Hatchback     225.0
# 41004    Mercedes       E Class  2016.0      Sedan   50000.0
# 41005       Mazda             6  2006.0      Combi  370000.0
# 41006     Renault  Grand Scenic  2006.0    Minivan  300000.0
#
#        Engine_capacity(cm3)     Fuel_type Transmission  Price(euro)
# 0                    1800.0        Hybrid    Automatic       7750.0
# 1                    1500.0        Diesel       Manual       8550.0
# 2                    1400.0        Petrol       Manual       2200.0
# 3                    1500.0        Diesel       Manual       6550.0
# 4                    1600.0  Metan/Propan       Manual       4100.0
# ...                     ...           ...          ...          ...
# 41002                1500.0        Diesel       Manual       7000.0
# 41003                1500.0        Diesel       Manual       4500.0
# 41004                1950.0        Diesel    Automatic      29500.0
# 41005                2000.0        Diesel       Manual       4000.0
# 41006                1500.0        Diesel       Manual       4000.0
#
# [41007 rows x 9 columns]

# %% [markdown]
# ## Коррекция типов данных

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41007 entries, 0 to 41006
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Make                  41007 non-null  object
#  1   Model                 41007 non-null  object
#  2   Year                  41007 non-null  float64
#  3   Style                 41007 non-null  object
#  4   Distance              41007 non-null  float64
#  5   Engine_capacity(cm3)  41007 non-null  float64
#  6   Fuel_type             41007 non-null  object
#  7   Transmission          41007 non-null  object
#  8   Price(euro)           41007 non-null  float64
# dtypes: float64(4), object(5)
# memory usage: 2.8+ MB

# %%
# Изменить float на int
data['Year'] = data['Year'].astype(int)
data['Engine_capacity(cm3)'] = data['Engine_capacity(cm3)'].astype(int)
data['Distance'] = data['Distance'].astype(int)
data['Price(euro)'] = data['Price(euro)'].astype(int)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41007 entries, 0 to 41006
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Make                  41007 non-null  object
#  1   Model                 41007 non-null  object
#  2   Year                  41007 non-null  int64
#  3   Style                 41007 non-null  object
#  4   Distance              41007 non-null  int64
#  5   Engine_capacity(cm3)  41007 non-null  int64
#  6   Fuel_type             41007 non-null  object
#  7   Transmission          41007 non-null  object
#  8   Price(euro)           41007 non-null  int64
# dtypes: int64(4), object(5)
# memory usage: 2.8+ MB

# %%
data
# Out:
#              Make         Model  Year      Style  Distance  \
# 0          Toyota         Prius  2011  Hatchback    195000
# 1         Renault  Grand Scenic  2014  Universal    135000
# 2      Volkswagen          Golf  1998  Hatchback         1
# 3         Renault        Laguna  2012  Universal    110000
# 4            Opel         Astra  2006  Universal    200000
# ...           ...           ...   ...        ...       ...
# 41002       Dacia         Logan  2015  Universal     89000
# 41003     Renault         Modus  2009  Hatchback       225
# 41004    Mercedes       E Class  2016      Sedan     50000
# 41005       Mazda             6  2006      Combi    370000
# 41006     Renault  Grand Scenic  2006    Minivan    300000
#
#        Engine_capacity(cm3)     Fuel_type Transmission  Price(euro)
# 0                      1800        Hybrid    Automatic         7750
# 1                      1500        Diesel       Manual         8550
# 2                      1400        Petrol       Manual         2200
# 3                      1500        Diesel       Manual         6550
# 4                      1600  Metan/Propan       Manual         4100
# ...                     ...           ...          ...          ...
# 41002                  1500        Diesel       Manual         7000
# 41003                  1500        Diesel       Manual         4500
# 41004                  1950        Diesel    Automatic        29500
# 41005                  2000        Diesel       Manual         4000
# 41006                  1500        Diesel       Manual         4000
#
# [41007 rows x 9 columns]

# %% [markdown]
# ## Обогащение данных

# %%
# Возраст автомобиля
data['Vehicle_age'] = (2025 - data['Year']) + 1
data['Vehicle_age'].value_counts()
# Out:
# Vehicle_age
# 14     2504
# 15     2502
# 11     2298
# 10     2290
# 13     2247
#        ...
# 78        1
# 111       1
# 58        1
# 65        1
# 72        1
# Name: count, Length: 75, dtype: int64

# %%
# Среднегодовой пробег
data['Avg_mileage'] = (data['Distance'] / data['Vehicle_age']).round().astype(int)
data['Avg_mileage'].value_counts()
# Out:
# Avg_mileage
# 0         1938
# 10000      480
# 15000      247
# 5000       228
# 12500      228
#           ...
# 99259        1
# 4302         1
# 653595       1
# 79365        1
# 8290         1
# Name: count, Length: 9744, dtype: int64

# %%
# Проверка на NaN
data['Avg_mileage'].isna().sum()
# Out:
# np.int64(0)

# %%
data['Vehicle_age'].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### **Проверка "очищенных" данных**

# %%
# Проверка дубликатов
data.duplicated().sum()
# Out:
# np.int64(3646)

# %%
data = data.drop_duplicates()
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 37361 entries, 0 to 41006
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Make                  37361 non-null  object
#  1   Model                 37361 non-null  object
#  2   Year                  37361 non-null  int64
#  3   Style                 37361 non-null  object
#  4   Distance              37361 non-null  int64
#  5   Engine_capacity(cm3)  37361 non-null  int64
#  6   Fuel_type             37361 non-null  object
#  7   Transmission          37361 non-null  object
#  8   Price(euro)           37361 non-null  int64
#  9   Vehicle_age           37361 non-null  int64
#  10  Avg_mileage           37361 non-null  int64
# dtypes: int64(6), object(5)
# memory usage: 3.4+ MB

# %%
data
# Out:
#              Make         Model  Year      Style  Distance  \
# 0          Toyota         Prius  2011  Hatchback    195000
# 1         Renault  Grand Scenic  2014  Universal    135000
# 2      Volkswagen          Golf  1998  Hatchback         1
# 3         Renault        Laguna  2012  Universal    110000
# 4            Opel         Astra  2006  Universal    200000
# ...           ...           ...   ...        ...       ...
# 41001  Land Rover    Freelander  2002  Crossover    225000
# 41002       Dacia         Logan  2015  Universal     89000
# 41003     Renault         Modus  2009  Hatchback       225
# 41005       Mazda             6  2006      Combi    370000
# 41006     Renault  Grand Scenic  2006    Minivan    300000
#
#        Engine_capacity(cm3)     Fuel_type Transmission  Price(euro)  \
# 0                      1800        Hybrid    Automatic         7750
# 1                      1500        Diesel       Manual         8550
# 2                      1400        Petrol       Manual         2200
# 3                      1500        Diesel       Manual         6550
# 4                      1600  Metan/Propan       Manual         4100
# ...                     ...           ...          ...          ...
# 41001                  1800  Metan/Propan       Manual         4400
# 41002                  1500        Diesel       Manual         7000
# 41003                  1500        Diesel       Manual         4500
# 41005                  2000        Diesel       Manual         4000
# 41006                  1500        Diesel       Manual         4000
#
#        Vehicle_age  Avg_mileage
# 0               15        13000
# 1               12        11250
# 2               28            0
# 3               14         7857
# 4               20        10000
# ...            ...          ...
# 41001           24         9375
# 41002           11         8091
# 41003           17           13
# 41005           20        18500
# 41006           20        15000
#
# [37361 rows x 11 columns]

# %% [markdown]
# # EDA

# %%
data.describe()[['Year', 'Distance', 'Engine_capacity(cm3)', 'Price(euro)', 'Vehicle_age',  'Avg_mileage']]
# Out:
#                Year      Distance  Engine_capacity(cm3)   Price(euro)  \
# count  37361.000000  3.736100e+04          37361.000000  3.736100e+04
# mean    2007.719333  4.747482e+05           1858.858810  9.570691e+03
# std        8.283279  4.585268e+06            707.238832  5.276579e+04
# min     1900.000000  0.000000e+00              0.000000  1.000000e+00
# 25%     2004.000000  9.000000e+04           1499.000000  3.303000e+03
# 50%     2009.000000  1.700000e+05           1800.000000  6.499000e+03
# 75%     2014.000000  2.300000e+05           2000.000000  1.179900e+04
# max     2021.000000  1.000000e+08           9999.000000  1.000000e+07
#
#         Vehicle_age   Avg_mileage
# count  37361.000000  3.736100e+04
# mean      18.280667  2.229166e+04
# std        8.283279  2.160892e+05
# min        5.000000  0.000000e+00
# 25%       12.000000  6.100000e+03
# 50%       17.000000  1.038500e+04
# 75%       22.000000  1.350000e+04
# max      126.000000  2.000000e+07

# %%
columns = ['Year', 'Distance', 'Engine_capacity(cm3)', 'Price(euro)']

for column in columns:
    data.hist(column, bins=30, log=True)

# %% [markdown]
# **Заключение**
#
# - Присутствует выбросы, которые мешают чтению данных

# %% [markdown]
# ## Изучение и обработка выбросов

# %%
outlier = data[columns]
outlier
# Out:
#        Year  Distance  Engine_capacity(cm3)  Price(euro)
# 0      2011    195000                  1800         7750
# 1      2014    135000                  1500         8550
# 2      1998         1                  1400         2200
# 3      2012    110000                  1500         6550
# 4      2006    200000                  1600         4100
# ...     ...       ...                   ...          ...
# 41001  2002    225000                  1800         4400
# 41002  2015     89000                  1500         7000
# 41003  2009       225                  1500         4500
# 41005  2006    370000                  2000         4000
# 41006  2006    300000                  1500         4000
#
# [37361 rows x 4 columns]

# %%
# Определить нижние пределы для выбросов
Q1 = outlier.quantile(0.25)
Q1
# Out:
# Year                     2004.0
# Distance                90000.0
# Engine_capacity(cm3)     1499.0
# Price(euro)              3303.0
# Name: 0.25, dtype: float64

# %%
# Определить верхние пределы выбросов
Q3 = outlier.quantile(0.75)
Q3
# Out:
# Year                      2014.0
# Distance                230000.0
# Engine_capacity(cm3)      2000.0
# Price(euro)              11799.0
# Name: 0.75, dtype: float64

# %%
# IQR-оценки
IQR = Q3-Q1
# Отфильтрованные данные, из которых удалены выбросы
data_filtered = outlier[~((outlier < (Q1 - 1.5 * IQR)) |(outlier > (Q3 + 1.5 * IQR))).any(axis=1)]
data_filtered = data_filtered[data_filtered['Distance'] > 2000]
data_filtered = data_filtered[data_filtered['Price(euro)'] >= 500]
data_filtered
# Out:
#        Year  Distance  Engine_capacity(cm3)  Price(euro)
# 0      2011    195000                  1800         7750
# 1      2014    135000                  1500         8550
# 3      2012    110000                  1500         6550
# 4      2006    200000                  1600         4100
# 5      2000    300000                  2200         3490
# ...     ...       ...                   ...          ...
# 41000  2016     88000                  1800        11500
# 41001  2002    225000                  1800         4400
# 41002  2015     89000                  1500         7000
# 41005  2006    370000                  2000         4000
# 41006  2006    300000                  1500         4000
#
# [27057 rows x 4 columns]

# %%
# Копирование индексов
index_list = list(data_filtered.index.values)

# %%
from sklearn.preprocessing import LabelEncoder
data_filtered = data[data.index.isin(index_list)]

categories = ['Make', 'Model', 'Style', 'Fuel_type', 'Transmission']
data_encoded = data_filtered.copy()

label_encoders = {}
for col in categories:
    le = LabelEncoder()
    data_encoded[col] = le.fit_transform(data_encoded[col])
    label_encoders[col] = le

data_encoded = data_encoded.drop(['Vehicle_age', 'Avg_mileage'], axis=1)
data_encoded.to_csv('filtered_moldova_cars_task.csv', index=False)
data_filtered.describe()
# Out:
#                Year       Distance  Engine_capacity(cm3)   Price(euro)  \
# count  27057.000000   27057.000000          27057.000000  27057.000000
# mean    2008.476882  181515.853568           1745.102266   7582.411539
# std        6.578939   84118.599565            367.807156   5248.922565
# min     1989.000000    2003.000000            750.000000    500.000000
# 25%     2005.000000  126663.000000           1461.000000   3500.000000
# 50%     2010.000000  180000.000000           1600.000000   6300.000000
# 75%     2013.000000  232000.000000           2000.000000  10500.000000
# max     2021.000000  440000.000000           2720.000000  24500.000000
#
#         Vehicle_age   Avg_mileage
# count  27057.000000  27057.000000
# mean      17.523118  10869.460731
# std        6.578939   4605.187233
# min        5.000000     65.000000
# 25%       13.000000   8100.000000
# 50%       16.000000  11059.000000
# 75%       21.000000  13727.000000
# max       37.000000  56000.000000

# %%
# создать гистограмму с отфильтрованным выбросом
filtered_outlier = data_filtered[columns]

for col in filtered_outlier:
    data_filtered.hist(col, bins=100)

# %% [markdown]
# ## Изучение основных параметров без выбросов

# %%
print (data.hist('Year', bins=100))
print (data_filtered.hist('Year', bins=100))
# Out:
# [[<Axes: title={'center': 'Year'}>]]
# [[<Axes: title={'center': 'Year'}>]]

# %%
print (data.hist('Distance', bins=100))
print (data_filtered.hist('Distance', bins=100))
# Out:
# [[<Axes: title={'center': 'Distance'}>]]
# [[<Axes: title={'center': 'Distance'}>]]

# %%
print (data.hist('Engine_capacity(cm3)', bins=100))
print (data_filtered.hist('Engine_capacity(cm3)', bins=100))
# Out:
# [[<Axes: title={'center': 'Engine_capacity(cm3)'}>]]
# [[<Axes: title={'center': 'Engine_capacity(cm3)'}>]]

# %%
print (data.hist('Price(euro)', bins=100))
print (data_filtered.hist('Price(euro)', bins=100))
# Out:
# [[<Axes: title={'center': 'Price(euro)'}>]]
# [[<Axes: title={'center': 'Price(euro)'}>]]

# %% [markdown]
# ## Средняя цена по типам кузова

# %%
avg_price_style = data_filtered.pivot_table(index='Style', values='Price(euro)', aggfunc='mean')
avg_price_style.sort_values(by='Price(euro)', ascending=False)
# Out:
#             Price(euro)
# Style
# Crossover  12512.450111
# SUV        11392.618079
# Pickup     10797.942029
# Roadster    8687.833333
# Sedan       7700.898183
# Cabriolet   6906.553398
# Microvan    6666.947917
# Coupe       6332.445205
# Universal   6249.484794
# Minivan     5948.711302
# Hatchback   5552.217796
# Combi       4844.385350

# %%
ads_style = data_filtered['Style'].value_counts().reset_index()
ads_style.columns = ['Style', 'Count']
ads_style = ads_style.sort_values(by='Count', ascending=False)
ads_style
# Out:
#         Style  Count
# 0       Sedan   7759
# 1   Universal   5557
# 2   Hatchback   5046
# 3   Crossover   3157
# 4     Minivan   2442
# 5         SUV   1770
# 6       Coupe    438
# 7    Microvan    384
# 8       Combi    314
# 9   Cabriolet    103
# 10     Pickup     69
# 11   Roadster     18

# %%
ads_style.plot(grid=True, figsize=(20, 7), kind = 'bar', x='Style',y='Count')
# Out:
# <Axes: xlabel='Style'>

# %% [markdown]
# **Заключение:**
#
# - Самые дорогие типы кузова: Crossover, Pickup, SUV, самые дешевые — Minivan, Hatchback, Combi.
#
# - Два самых популярных типа:
#      - Sedan
#      - Universal

# %% [markdown]
# ## Ценовые факторы

# %% [markdown]
# ### Возраст автомобиля и цена

# %%
#2 популярных типа
sedan = data_filtered.query('Style == "Sedan"')
universal = data_filtered.query('Style == "Universal"')

# %%
sns.lmplot(x="Vehicle_age", y="Price(euro)", data=sedan)
plt.title('Sedan')
sns.lmplot(x="Vehicle_age", y="Price(euro)", data=universal)
plt.title('Universal')
# Out:
# Text(0.5, 1.0, 'Universal')

# %%
# вычисление корелляции
age_sedan = sedan[['Vehicle_age','Price(euro)']]
corr_sedan = age_sedan.corr()
age_universal = sedan[['Vehicle_age','Price(euro)']]
corr_universal = age_universal.corr()

# %%
round(corr_sedan,3)
# Out:
#              Vehicle_age  Price(euro)
# Vehicle_age         1.00        -0.73
# Price(euro)        -0.73         1.00

# %%
round(corr_universal,3)
# Out:
#              Vehicle_age  Price(euro)
# Vehicle_age         1.00        -0.73
# Price(euro)        -0.73         1.00

# %% [markdown]
# **Заключение** :
# <br>
# Возраст ТС для обоих типов повлиял на его стоимость. Увеличение возраста ТС приведет к снижению цены. Коэффициент корреляции отрицательный означает, что возраст уменьшается с ростом цены.

# %% [markdown]
# ### Пробег и цена

# %%
sns.lmplot(x="Distance", y="Price(euro)", data=sedan, height = 5, aspect =3)
plt.title('Sedan')
sns.lmplot(x="Distance", y="Price(euro)", data=universal, height = 5, aspect =3)
plt.title('Universal')
# Out:
# Text(0.5, 1.0, 'Universal')

# %%
# вычисление корелляции
distance_sedan= sedan[['Distance','Price(euro)']]
distance_sedan_corr = distance_sedan.corr(method='spearman')
distance_universal = universal[['Distance','Price(euro)']]
distance_universal_corr = distance_universal.corr(method='spearman')

# %%
round(distance_sedan_corr,3)
# Out:
#              Distance  Price(euro)
# Distance        1.000       -0.329
# Price(euro)    -0.329        1.000

# %%
round(distance_universal_corr,3)
# Out:
#              Distance  Price(euro)
# Distance        1.000       -0.293
# Price(euro)    -0.293        1.000

# %% [markdown]
# **Заключение:**
# <br>Пробег влияет на стоимость ТС. Увеличение пробега ТС приведет к снижению цены. Коэффициент корреляции отрицательный, означает, что пробег уменьшается с ростом цены.

# %% [markdown]
# ### Трансмиссия и цена

# %%
sedan_trans = sedan['Transmission'].value_counts()
sedan_trans_valid = sedan_trans[sedan_trans >= 50].index
sedan_filtered = sedan[sedan['Transmission'].isin(sedan_trans_valid)]
sedan_filtered.Transmission.value_counts()
# Out:
# Transmission
# Manual       3957
# Automatic    3802
# Name: count, dtype: int64

# %%
universal_trans = universal['Transmission'].value_counts()
universal_trans_valid = universal_trans[universal_trans >= 50].index
universal_filtered = universal[universal['Transmission'].isin(universal_trans_valid)]
universal_filtered.Transmission.value_counts()
# Out:
# Transmission
# Manual       4193
# Automatic    1364
# Name: count, dtype: int64

# %%
sedan_filtered.boxplot(by ='Transmission', column ='Price(euro)', grid = True)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.title('Sedan')
# Out:
# Text(0.5, 1.0, 'Sedan')

# %%
universal_filtered.boxplot(by ='Transmission', column ='Price(euro)', grid = True)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.title('Universal')
# Out:
# Text(0.5, 1.0, 'Universal')

# %% [markdown]
# **Заключение**
# - В среднем обе модели автомобилей с автоматической коробкой передач дороже, чем с механической
# - Цены на автомат у обеих моделей варьируются сильнее, чем цены на механику

# %% [markdown]
# ### Топливо и цена

# %%
sedan_fuel = sedan['Fuel_type'].value_counts()
sedan_fuel_valid = sedan_fuel[sedan_fuel >= 50].index
sedan_fuel_filtered = sedan[sedan['Fuel_type'].isin(sedan_fuel_valid)]
sedan_fuel_filtered.Fuel_type.value_counts()
# Out:
# Fuel_type
# Petrol            3517
# Diesel            2305
# Metan/Propan      1156
# Hybrid             653
# Plug-in Hybrid     125
# Name: count, dtype: int64

# %%
universal_fuel = universal['Fuel_type'].value_counts()
universal_fuel_valid = universal_fuel[universal_fuel >= 50].index
universal_fuel_filtered = universal[universal['Fuel_type'].isin(universal_fuel_valid)]
universal_fuel_filtered.Fuel_type.value_counts()
# Out:
# Fuel_type
# Diesel          3399
# Petrol          1355
# Metan/Propan     598
# Hybrid           168
# Name: count, dtype: int64

# %% [markdown]
# Как для внедорожника, так и для седана, трансмиссия отображает все данные выше 50. Поэтому нет необходимости фильтровать данные.

# %%
sedan_fuel_filtered.boxplot(by='Fuel_type', column='Price(euro)', grid=True)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.title('Sedan')
# Out:
# Text(0.5, 1.0, 'Sedan')

# %%
universal_fuel_filtered.boxplot(by='Fuel_type', column='Price(euro)', grid=True)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.title('Universal')
# Out:
# Text(0.5, 1.0, 'Universal')

# %% [markdown]
# # Общие выводы:

# %% [markdown]
# Этот проект призван изучить данные, и определить, какие факторы влияют на цену ТС. Вначале, после загрузки данных и всех необходимых библиотек, образцы данных и общее резюме выводятся на экран для их анализа. Необходимо выявить "аномальные" данные, отсутствующие значения и некорректные типы данных.
#
# Заполнить пропущенные значения, сравнив их с другими столбцами (если они связаны):
#
# - Model: Заполнить пропущенные значения на основе наиболее часто встречающихся моделей для каждого производителя
# - Year: Заполнить пропущенные значения медианным годом выпуска для каждой модели или производителя.
# - Transmission: Заполнить пропуски наиболее часто встречающимся типом трансмиссии для каждой модели или производителя.
# - Distance: Заполнить пропущенные значения медианным пробегом для автомобилей с аналогичными характеристиками.
# - Style: Заполнить пропущенные значения наиболее часто встречающимся стилем кузова для каждой модели или производителя.
# <br>
#
# **Изменение типа данных:**
#
# - Тип данных столбцов 'Year', 'Engine_capacity', 'Distance' и 'Price' изменен на int.
#
# <br>
#
# **Редактирование данных:**
# <br>
#
# - Добавили возраст ТС.
# - Добавили средний пробег ТС.
# - Проверка дублированных данных и их удаление.
# <br>
#
# **Проверка выбросов**
#
# **Удаление выбросов**
#
# **Изучение ценового фактора:**
#
# возраст, пробег, тип трансмиссии и топливо.
