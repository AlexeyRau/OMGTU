# %%
import random
import time
from enum import Enum, auto
from typing import List, Dict, Tuple, Optional, Set

# %%
# Перечисление для времени суток
class TimeOfDay(Enum):
    MORNING = auto()  # Утро
    DAY = auto()      # День
    EVENING = auto()  # Вечер
    NIGHT = auto()    # Ночь

# Класс, представляющий мир - основное окружение для симуляции
class World:
    def __init__(self, width: int, height: int):
        self.width = width    # Ширина мира в клетках
        self.height = height  # Высота мира в клетках
        # Сетка мира (двумерный список). None - пустая клетка
        self.grid = [[None for _ in range(width)] for _ in range(height)]
        self.time_of_day = TimeOfDay.MORNING  # Текущее время суток
        self.time_ticks = 0    # Счетчик шагов симуляции
        self.entities = []     # Список всех существ в мире
        self.day_counter = 0   # Счетчик дней

    # Добавление существа в указанные координаты
    def add_entity(self, entity, x: int, y: int):
        # Проверка выхода за границы мира
        if not (0 <= x < self.width and 0 <= y < self.height):
            return False

        # Проверка, что клетка пуста
        if self.grid[y][x] is not None:
            return False

        # Установка координат существа и ссылки на мир
        entity.x = x
        entity.y = y
        entity.world = self
        # Размещение в сетке и добавление в общий список
        self.grid[y][x] = entity
        self.entities.append(entity)
        return True

    # Удаление существа из мира
    def remove_entity(self, entity):
        if entity in self.entities:
            self.entities.remove(entity)
        # Очистка клетки, если в ней находится это существо
        if (0 <= entity.x < self.width and
            0 <= entity.y < self.height and
            self.grid[entity.y][entity.x] == entity):
            self.grid[entity.y][entity.x] = None

    # Получение списка соседних клеток (включая диагонали)
    def get_neighbors(self, x: int, y: int) -> List[Tuple[int, int]]:
        neighbors = []
        for dx in [-1, 0, 1]:
            for dy in [-1, 0, 1]:
                if dx == 0 and dy == 0:  # Исключаем текущую клетку
                    continue
                nx, ny = x + dx, y + dy
                # Проверка, что координаты в пределах мира
                if 0 <= nx < self.width and 0 <= ny < self.height:
                    neighbors.append((nx, ny))
        return neighbors

    # Обновление времени в мире
    def update_time(self):
        self.time_ticks += 1
        # Каждые 6 шагов меняется время суток
        if self.time_ticks % 6 == 0:
            prev_time = self.time_of_day
            # Циклическое изменение времени суток: Утро -> День -> Вечер -> Ночь -> Утро...
            self.time_of_day = {
                TimeOfDay.MORNING: TimeOfDay.DAY,
                TimeOfDay.DAY: TimeOfDay.EVENING,
                TimeOfDay.EVENING: TimeOfDay.NIGHT,
                TimeOfDay.NIGHT: TimeOfDay.MORNING
            }[self.time_of_day]
            
            # Увеличиваем счетчик дней при переходе от ночи к утру
            if prev_time == TimeOfDay.NIGHT and self.time_of_day == TimeOfDay.MORNING:
                self.day_counter += 1

    # Один шаг симуляции
    def step(self):
        self.update_time()  # Сначала обновляем время

        # Обрабатываем растения
        for entity in self.entities[:]:  # Копия списка для безопасного изменения
            if isinstance(entity, Plant):
                entity.grow()  # Растения растут
        
        # Обрабатываем животных в случайном порядке
        for entity in random.sample(self.entities[:], len(self.entities[:])):
            if isinstance(entity, Animal):
                entity.update_behavior()  # Обновление поведения
                entity.move()            # Движение
                entity.eat()             # Питание
                entity.reproduce()       # Размножение
                entity.update_hunger()   # Обновление уровня голода

                # Удаление, если энергия исчерпана
                if entity.energy <= 0:
                    self.remove_entity(entity)

    # Отображение текущего состояния мира в консоли
    def display(self):
        # Соответствие времени суток и его названия
        time_names = {
            TimeOfDay.MORNING: "Утро",
            TimeOfDay.DAY: "День",
            TimeOfDay.EVENING: "Вечер",
            TimeOfDay.NIGHT: "Ночь"
        }
        print(f"День: {self.day_counter} Время: {time_names[self.time_of_day]} (Шаг: {self.time_ticks})")
        print(f"Существ: {len(self.entities)} (Растений: {sum(1 for e in self.entities if isinstance(e, Plant))}, "
              f"Травоядных: {sum(1 for e in self.entities if isinstance(e, Pauvre))}, "
              f"Хищников: {sum(1 for e in self.entities if isinstance(e, Malheureux))})")

        # Отображение сетки
        for y in range(self.height):
            row = []
            for x in range(self.width):
                entity = self.grid[y][x]
                if entity is None:
                    row.append('.')  # Пустая клетка
                elif isinstance(entity, Lumiere):
                    # 'L' - активно, 'l' - неактивно
                    row.append('L' if entity.active else 'l')
                elif isinstance(entity, Obscurite):
                    row.append('O' if entity.active else 'o')
                elif isinstance(entity, Demi):
                    row.append('D' if entity.active else 'd')
                elif isinstance(entity, Pauvre):
                    # 'P' - бодрствует, 'p' - спит
                    row.append('P' if not entity.sleeping else 'p')
                elif isinstance(entity, Malheureux):
                    row.append('M' if not entity.sleeping else 'm')
            print(' '.join(row))
        print()

# Базовый класс для растений
class Plant:
    def __init__(self):
        self.x = 0          # Координата X
        self.y = 0          # Координата Y
        self.world = None   # Ссылка на мир
        self.growth_rate = 1  # Скорость роста
        self.active = False  # Активен ли рост
        self.health = 100    # Здоровье растения

    # Проверка, может ли растение расти в текущее время суток
    def can_grow_in_time(self, time_of_day: TimeOfDay) -> bool:
        raise NotImplementedError  # Абстрактный метод

    # Процесс роста растения
    def grow(self):
        if self.world is None:
            return

        # Проверка активности в текущее время
        self.active = self.can_grow_in_time(self.world.time_of_day)
        
        if not self.active:
            return

        # Восстановление здоровья при активности
        self.health = min(100, self.health + 5)
        
        # Получение соседей в случайном порядке
        neighbors = self.world.get_neighbors(self.x, self.y)
        random.shuffle(neighbors)
        
        # Попытка распространения на соседние клетки
        for nx, ny in neighbors:
            target = self.world.grid[ny][nx]
            
            # Если клетка пуста - попытка размножения
            if target is None and random.random() < 0.2:
                new_plant = self.__class__()
                if self.world.add_entity(new_plant, nx, ny):
                    continue
            # Если в клетке другое растение - попытка вытеснения
            elif (isinstance(target, Plant) and 
                  target != self and 
                  self.active and not target.active and 
                  random.random() < 0.3):
                target.health -= 20
                if target.health <= 0:
                    self.world.remove_entity(target)
                    new_plant = self.__class__()
                    self.world.add_entity(new_plant, nx, ny)

    def __str__(self):
        return f"{self.__class__.__name__} в ({self.x}, {self.y})"

# Класс растения Lumiere (растет днем)
class Lumiere(Plant):
    def can_grow_in_time(self, time_of_day: TimeOfDay) -> bool:
        return time_of_day == TimeOfDay.DAY

# Класс растения Obscurite (растет ночью)
class Obscurite(Plant):
    def can_grow_in_time(self, time_of_day: TimeOfDay) -> bool:
        return time_of_day == TimeOfDay.NIGHT

# Класс растения Demi (растет утром и вечером)
class Demi(Plant):
    def can_grow_in_time(self, time_of_day: TimeOfDay) -> bool:
        return time_of_day in (TimeOfDay.MORNING, TimeOfDay.EVENING)

# Базовый класс для животных
class Animal:
    def __init__(self):
        self.x = 0          # Координата X
        self.y = 0          # Координата Y
        self.world = None   # Ссылка на мир
        self.energy = 100   # Уровень энергии
        self.hunger = 0     # Уровень голода
        self.sleeping = False  # Спящий режим
        self.age = 0        # Возраст (в шагах симуляции)

    # Обновление поведения животного
    def update_behavior(self):
        if self.world is None:
            return
        self.age += 1
        self.modify_behavior()  # Вызов специфичного поведения

    # Абстрактный метод для изменения поведения
    def modify_behavior(self):
        raise NotImplementedError

    # Движение животного
    def move(self):
        if self.sleeping or self.world is None:
            return

        # Возможные клетки для движения (пустые или с растениями)
        possible_moves = [pos for pos in self.world.get_neighbors(self.x, self.y)
                         if self.world.grid[pos[1]][pos[0]] is None or 
                         (isinstance(self.world.grid[pos[1]][pos[0]], Plant) and 
                         random.random() < 0.3)]
        
        # Перемещение с учетом скорости
        if possible_moves and random.random() < self.get_speed():
            nx, ny = random.choice(possible_moves)
            self.world.grid[self.y][self.x] = None
            self.x, self.y = nx, ny
            self.world.grid[ny][nx] = self
            self.energy -= 1  # Затраты энергии на движение

    # Расчет скорости движения (зависит от голода)
    def get_speed(self) -> float:
        return max(0.1, 1.0 - (self.hunger / 200))

    # Процесс питания
    def eat(self):
        if self.sleeping or self.hunger < 20 or self.world is None:
            return

        # Поиск пищи среди соседей
        for nx, ny in self.world.get_neighbors(self.x, self.y):
            target = self.world.grid[ny][nx]
            if target is None:
                continue
                
            # Проверка, является ли цель пищей
            if any(isinstance(target, food_type) for food_type in self.get_food_types()):
                nutrition = self.get_nutrition(target)
                self.world.remove_entity(target)
                self.hunger = max(0, self.hunger - nutrition)
                self.energy += nutrition / 2
                return

    # Абстрактный метод для получения типов пищи
    def get_food_types(self) -> Tuple:
        raise NotImplementedError

    # Получение питательной ценности пищи
    def get_nutrition(self, food) -> int:
        if isinstance(food, Plant):
            return 30
        elif isinstance(food, Animal):
            return 50
        return 0

    # Обновление уровня голода
    def update_hunger(self):
        self.hunger += 2
        if self.hunger > 100:  # Голод снижает энергию
            self.energy -= 5

    # Процесс размножения
    def reproduce(self):
        # Условия для размножения: достаточно энергии, не голоден, случайный шанс
        if (self.energy < 80 or 
            self.hunger > 50 or 
            random.random() > 0.05 or 
            self.world is None):
            return

        # Поиск партнера для размножения среди соседей
        for nx, ny in self.world.get_neighbors(self.x, self.y):
            target = self.world.grid[ny][nx]
            if (target is not None and 
                isinstance(target, self.__class__) and 
                target != self and 
                target.energy > 70 and 
                target.hunger < 50):
                
                # Поиск пустой клетки для потомства
                for cx, cy in self.world.get_neighbors(self.x, self.y):
                    if self.world.grid[cy][cx] is None:
                        new_animal = self.__class__()
                        new_animal.energy = 60
                        if self.world.add_entity(new_animal, cx, cy):
                            self.energy -= 30
                            target.energy -= 30
                            return

    def __str__(self):
        return f"{self.__class__.__name__} в ({self.x}, {self.y})"

# Класс травоядного животного Pauvre
class Pauvre(Animal):
    def __init__(self):
        super().__init__()
        self.aggression = 0    # Уровень агрессии
        self.group = set()     # Группа особей
        self.group_size = 1    # Размер группы

    # Изменение специфичного поведения
    def modify_behavior(self):
        # Сон ночью
        self.sleeping = (self.world.time_of_day == TimeOfDay.NIGHT)
        
        # Агрессия зависит от голода и размера группы
        self.aggression = min(100, self.hunger * 0.8 + len(self.group) * 5)
        
        # Обновление состава группы
        self.update_group()

    # Обновление группы особей
    def update_group(self):
        self.group = {self}
        # Поиск особей в радиусе 3 клеток
        for dx in range(-3, 4):
            for dy in range(-3, 4):
                nx, ny = self.x + dx, self.y + dy
                if (0 <= nx < self.world.width and 
                    0 <= ny < self.world.height and 
                    isinstance(self.world.grid[ny][nx], Pauvre)):
                    self.group.add(self.world.grid[ny][nx])
        
        self.group_size = len(self.group)
        
        # Разделение группы при перенаселении
        if self.group_size > 5 and random.random() < 0.1:
            self.split_group()

    # Разделение группы на две подгруппы
    def split_group(self):
        # Вычисление центра масс группы
        avg_x = sum(m.x for m in self.group) / len(self.group)
        avg_y = sum(m.y for m in self.group) / len(self.group)
        
        # Разделение на две группы относительно центра
        subgroup1 = set()
        subgroup2 = set()
        
        for member in self.group:
            if member.x < avg_x or (member.x == avg_x and member.y < avg_y):
                subgroup1.add(member)
            else:
                subgroup2.add(member)
        
        # Попытка разойтись в пространстве
        for member in subgroup1:
            # Движение влево или вверх
            dx = -1 if random.random() < 0.5 else 0
            dy = -1 if dx == 0 else 0
            nx, ny = member.x + dx, member.y + dy
            if (0 <= nx < self.world.width and 
                0 <= ny < self.world.height and 
                self.world.grid[ny][nx] is None):
                self.world.grid[member.y][member.x] = None
                member.x, member.y = nx, ny
                self.world.grid[ny][nx] = member

    # Типы пищи (только Lumiere)
    def get_food_types(self) -> Tuple:
        return (Lumiere,)

    # Питательная ценность пищи (зависит от времени суток)
    def get_nutrition(self, food) -> int:
        if isinstance(food, Lumiere):
            # Больше питательных веществ утром
            if self.world.time_of_day == TimeOfDay.MORNING:
                return 50
            elif self.world.time_of_day == TimeOfDay.EVENING:
                return 20
            return 30
        return 0

    # Процесс питания с учетом агрессии
    def eat(self):
        if self.sleeping or self.hunger < 20 or self.world is None:
            return

        # Сначала пробуем съесть растения
        super().eat()
        
        # Если голодны и агрессивны - атакуем других травоядных не из своей группы
        if self.hunger > 50 and self.aggression > 60:
            for nx, ny in self.world.get_neighbors(self.x, self.y):
                target = self.world.grid[ny][nx]
                if (isinstance(target, Pauvre) and 
                    target not in self.group and 
                    random.random() < 0.3):
                    
                    damage = min(20, self.aggression / 3)
                    target.energy -= damage
                    self.energy -= 5
                    self.hunger = max(0, self.hunger - 10)
                    return

# Класс хищника Malheureux
class Malheureux(Animal):
    def __init__(self):
        super().__init__()
        self.pack = set()    # Стая
        self.hunting = False # Режим охоты

    # Изменение специфичного поведения
    def modify_behavior(self):
        # Активны на рассвете и закате
        self.sleeping = (self.world.time_of_day in (TimeOfDay.DAY, TimeOfDay.NIGHT))
        
        # Охотничий режим при голоде и активности
        self.hunting = (not self.sleeping and self.hunger > 40)
        
        # Обновление состава стаи
        self.update_pack()

    # Обновление стаи
    def update_pack(self):
        self.pack = {self}
        # Поиск особей в радиусе 2 клеток
        for dx in range(-2, 3):
            for dy in range(-2, 3):
                nx, ny = self.x + dx, self.y + dy
                if (0 <= nx < self.world.width and 
                    0 <= ny < self.world.height and 
                    isinstance(self.world.grid[ny][nx], Malheureux)):
                    self.pack.add(self.world.grid[ny][nx])
        
        # Повышение агрессии при большом размере стаи
        if len(self.pack) > 3:
            for member in self.pack:
                member.aggression = True

    # Типы пищи (растения Demi, Obscurite и травоядные Pauvre)
    def get_food_types(self) -> Tuple:
        return (Demi, Obscurite, Pauvre)

    # Скорость движения с учетом режима охоты
    def get_speed(self) -> float:
        base_speed = super().get_speed()
        if self.hunting:
            return base_speed * 1.2  # Быстрее при охоте
        return base_speed * 0.8      # Медленнее в обычном режиме

    # Процесс питания с учетом охоты
    def eat(self):
        if self.sleeping or self.hunger < 20 or self.world is None:
            return

        # Сначала пробуем съесть растения
        super().eat()
        
        # Если в режиме охоты и голодны - атакуем травоядных
        if self.hunting and self.hunger > 40:
            for nx, ny in self.world.get_neighbors(self.x, self.y):
                target = self.world.grid[ny][nx]
                if isinstance(target, Pauvre) and random.random() < 0.4:
                    # Бонус за размер стаи
                    pack_bonus = 1.0 + (len(self.pack) * 0.2)
                    damage = min(30, 15 * pack_bonus)
                    target.energy -= damage
                    self.energy -= 5
                    self.hunger = max(0, self.hunger - 25)
                    
                    # Удаление жертвы, если погибла
                    if target.energy <= 0:
                        self.world.remove_entity(target)
                    return

# Инициализация мира с существами
def initialize_world(world: World, plant_density: float = 0.2, 
                    pauvre_count: int = 10, malheureux_count: int = 5):
    plant_classes = [Lumiere, Obscurite, Demi]  # Доступные типы растений
    
    # Расчет количества растений на основе плотности
    num_plants = int(world.width * world.height * plant_density)
    
    # Добавление растений
    for _ in range(num_plants):
        while True:
            x, y = random.randint(0, world.width-1), random.randint(0, world.height-1)
            if world.grid[y][x] is None:
                plant_class = random.choice(plant_classes)
                plant = plant_class()
                if world.add_entity(plant, x, y):
                    break
    
    # Добавление травоядных
    for _ in range(pauvre_count):
        while True:
            x, y = random.randint(0, world.width-1), random.randint(0, world.height-1)
            if world.grid[y][x] is None:
                pauvre = Pauvre()
                if world.add_entity(pauvre, x, y):
                    break
    
    # Добавление хищников
    for _ in range(malheureux_count):
        while True:
            x, y = random.randint(0, world.width-1), random.randint(0, world.height-1)
            if world.grid[y][x] is None:
                malheureux = Malheureux()
                if world.add_entity(malheureux, x, y):
                    break

# Запуск симуляции
def run_simulation(width: int = 20, height: int = 20, 
                   plant_density: float = 0.2, 
                   pauvre_count: int = 10, malheureux_count: int = 5,
                   steps: int = 100, delay: float = 0.5):
    # Создание мира
    world = World(width, height)
    # Инициализация существ
    initialize_world(world, plant_density, pauvre_count, malheureux_count)
    
    try:
        # Основной цикл симуляции
        for _ in range(steps):
            world.step()      # Шаг симуляции
            world.display()   # Отображение состояния
            time.sleep(delay) # Задержка для удобства наблюдения
    except KeyboardInterrupt:
        print("\nСимуляция остановлена пользователем.")
    except Exception as e:
        print(f"Ошибка: {e}")
    
    # Вывод итоговой статистики
    print("Симуляция завершена.")
    print(f"Итоговые показатели: День {world.day_counter}, Всего существ: {len(world.entities)}")
    print(f"Растений: {sum(1 for e in world.entities if isinstance(e, Plant))}")
    print(f"Травоядных: {sum(1 for e in world.entities if isinstance(e, Pauvre))}")
    print(f"Хищников: {sum(1 for e in world.entities if isinstance(e, Malheureux))}")

# Точка входа в программу
if __name__ == "__main__":
    # Параметры симуляции:
    run_simulation(
        width=20,            # Ширина мира
        height=20,           # Высота мира
        plant_density=0.2,   # Плотность растений (0.0 - 1.0)
        pauvre_count=15,     # Начальное количество травоядных
        malheureux_count=5,  # Начальное количество хищников
        steps=200,           # Количество шагов симуляции
        delay=0.3            # Задержка между шагами (сек)
    )
# Out:
# Day: 0 Time: Morning (Tick: 1)
# Entities: 138 (Plants: 117, Pauvres: 16, Malheureux: 5)
# . . . . . . . l o . . . . . . . P l P o
# l . . . P . d o . . . . . o o . . D . o
# . . . . . D . . . . . . . . . P D d P D
# . . . . d d . . . . . M . . . d . o . D
# . . . . . . l . . . . . . . . . . o d D
# . l . . . d D o . . . . o l . . l . . l
# . . . . . . . d D . . l d d l d . . . .
# D . . . . . . . . . P . D . d D . . . .
# . . . . . . D . . . . l . . . d . . . .
# . . . o . . . d . d D l . . . l d d . .
# . . . . . D . . D . d . o . . d D . P D
# . P . . d P . . . . P . . P . o d . d .
# D d . . o . . d M . . . . . P . . . . .
# l . . . . . . D D . . l . l . . D o o d
# . . . . . . D . . d . . . . . P d D D l
# l . . . P . l . . . . P . M . . . d d .
# . d D . . . o . o . . l . . . . . D . .
# D d . d l . . . o D d . . . . l . l d .
# . o . . . . . M . D . . o . . . . M . .
# . . . . o o P . . d . . . . . . . . . .
#
# Day: 0 Time: Morning (Tick: 2)
# Entities: 178 (Plants: 157, Pauvres: 16, Malheureux: 5)
# . . . . d P . l o . . . . . . . . P . o
# l . . . . d D o . . . . . o o P d D d o
# . . . . . D . . . . . . . . . . D D . D
# . . . . D D d . . . M . . . P D d o P D
# . . . . . d l . . . . . . . . . . o D D
# . l . . . D D o d . . . o l . . l d . l
# . d . . . . . D D . . l D D l D . . . .
# D . . . . . . d . d . . D d D D d . . .
# . d . . . d D . d P d l . . d D . . . .
# . . . o . . d D . D D l . . d l D D P .
# . P . . d D . d D . D . o . . D D d . D
# . . . . D . d . d . . . . . . o D d D .
# D D d . o . P D M . P . P . . P d . d d
# l . . . . . d D D d . l . l . P D o o D
# . . . P . . D . . D . . . . . . D D D l
# l . . . . . l . . . d . P . . . . D D d
# d D D . d . o . o . . l . . M . d D . .
# D D . D l . . . o D D . . . . l . l D .
# . o . . . P . . . D d . o . . . . M . .
# . . . . o o . M . D . . . . . . . . . .
#
# Day: 0 Time: Morning (Tick: 3)
# Entities: 222 (Plants: 201, Pauvres: 16, Malheureux: 5)
# . . . . D . . l o . . . . . . . P . . o
# l . . . . P D o . . . . . o o . D D D o
# . . . . d D d . . . . . . . P . D D P D
# . . . . D D D . . . . M . . . D D o . D
# . . . . . D l d . . . . . . P d . o D D
# . l . . d D D o D . . . o l d . l D d l
# . D . . . d d D D . . l D D l D d . . .
# D d . . . . d D d D P d D D D D D . . .
# . D . . . D D . D . D l d d D D d . . .
# . . . o . d D D . D D l . . D l D D . d
# P . . . D D d D D . D d o . . D D D P D
# d d d . D d D d M . . . . . d P D D D .
# D D D d o P . D . P . . . . . . D . D D
# l . d P . d D D D D . P . l . . D d o D
# . . . . . . D . d D . . . . P . D D D l
# l d . d . d l d . . D . . P . . d D D D
# D D D . D d o . o . . l . . . . D D d d
# D D d D l . . . o D D d . . M l . l D .
# . o . . . . . . . D D . o . . . . . . .
# . . . . o o P M . D d . . . . . . M . .
#
# Day: 0 Time: Morning (Tick: 4)
# Entities: 283 (Plants: 262, Pauvres: 16, Malheureux: 5)
# . . . . D d P l o . . . . . . d . P d o
# l . . . d . D o . . . . . o o . D D D o
# . . . d D D D . . . . . . . . d D D . D
# . . . . D D D d . . . . . P . P D o d P
# . . . . . D l D d . . . M d . D . o D D
# . l . . D D D o D . . . o l D d l D D l
# d D d . . D D D D d d l D D d D D . d d
# D D d . . d D D D D P D D D D D D . . .
# d D d . . D D d D . D l D D D D D d . .
# P . . o d D D D d D D l . d D l D D P D
# . . d . D D D D D d D D o d d D D D . D
# D D D d D D D D . M d d d . D P D D D d
# D D D D P . d D d . . P . . . d D . D D
# l d D . P D D D P D . . . l P d D D d D
# . . d . . d D d D D d . . . . d D D D d
# l D d D . D l D d d D . . . . . D D D D
# D D D . D D o . o . d l d P M d D D D D
# D D D D l . . . o D D D . . . l d l D d
# d o . d . . . P d D D d o . . . . d . .
# . . . . o o M . . D D d . . . . . . M .
#
# Day: 0 Time: Morning (Tick: 5)
# Entities: 331 (Plants: 310, Pauvres: 16, Malheureux: 5)
# . . . d D D . l o . . . . . . D d . D o
# l . . . D d P o . . . . . o o . D P D o
# . . . D D D D d d . . . . . . P D D P D
# . . d d D D D D . . . . . . P . D o D .
# . . . . d D d D D . . . M D d D d o D D
# . l . . D D D d D d . d o l D D d D D d
# D D D d . D D D D P D d D D D D D d D D
# D D D . d D D D D D . D D D D D D d d .
# D D D d . D D D D d D l D D D D D D P .
# P d . o D D D D D D D l d D D d D D . D
# . . D d D D D D D D D D o D D D D D d D
# D D D D D D D D d . M D D . D . D D D D
# D D D P . . D D D P d . . . P D D d D D
# l D D P . D D D . D P . . P . D D D D D
# . d D d . D D D D D D . . . d D D D D D
# l D D D d D l D D D D d . M P d D D D D
# D D D d D D o d o d D l D . . D D D D D
# D D D D d . d . d D D D . . . l D d D D
# D o . D . . M . D D D D o . . d . D d M
# d d d . o o P . d D D D d . . . . . . .
#
# Day: 0 Time: Day (Tick: 6)
# Entities: 338 (Plants: 317, Pauvres: 16, Malheureux: 5)
# l . . d d d . L o . . . . . . d P . d o
# L l . . d P . o . . . . . o o . d . d l
# l l . d d d d d d . . . . P P . d d . d
# . . d d d d d d . . . . . . . . d P d .
# . . . . d d d d d . . . m d d d d o d d
# . L . . d d d d d d . d o L d d d d d d
# d d d d . d d d d . d d d d d d d d d d
# d d d . d d d d d P . d d d d d d d d P
# d d d d . d d d d d d L d d d d d d . .
# . P . o d d d d d d d L d d d d d d . d
# . . d d d d d d d d d d o d d d d d d d
# d d P d d d d d d . m d d . d . d d d d
# d d d . . . d d P . d . . P . d d d d d
# L d d . P d d d . d P . l . . d d d d d
# . d d d . d d d d d d . . P d d d d d d
# L d d d d d L d d d d d . m . d d d d d
# d d d d d d o d o d d L d P l d d d d d
# d d d d d . d . d d d d . . . L d d d d
# d o . d . P m . d d d d o . l d . d d m
# d d d . o o . . d d d d d . . . . . . .
#
# Day: 0 Time: Day (Tick: 7)
# Entities: 352 (Plants: 331, Pauvres: 16, Malheureux: 5)
# L l . d d d P L o . . . . . . d . P d o
# L L . . d . . o l . . . . o o . d . d L
# L L . d d d d d d . . . . . . . d d . d
# . . d d d d d d . . . . P P . . d . d l
# . . . . d d d d d . . . m d d d P o d d
# l L . . d d d d d d . d o L d d d d d d
# d d d d . d d d d P d d d d d d d d d d
# d d d . d d d d d . . d d d d d d d d .
# d d d d . d d d d d d L d d d d d d . P
# . . P o d d d d d d d L d d d d d d . d
# . . d d d d d d d d d d o d d d d d d d
# d d . P d d d d d P m d d . d . d d d d
# d d d . . . d d . P d l l . . d d d d d
# L d d P . d d d . d . . P . P d d d d d
# . d d d . d d d d d d l . . d d d d d d
# L d d d d d L d d d d d . m l d d d d d
# d d d d d d o d o d d L d P L d d d d d
# d d d d d P d . d d d d . l l L d d d d
# d o . d . . m . d d d d o l L d . d d m
# d d d . o o . . d d d d d l l . . . . .
#
# Day: 0 Time: Day (Tick: 8)
# Entities: 362 (Plants: 341, Pauvres: 16, Malheureux: 5)
# L L . d d d . L o l . . . . . d . . d o
# L L l . d . P o L . . . . o o . d P d L
# L L . d d d d d d . . . . . . . d d . d
# l l d d d d d d . . . . . . P . d l d L
# . . . . d d d d d . . P m d d d . o d d
# L L . . d d d d d d . d o L d d P d d d
# d d d d . d d d d . d d d d d d d d d d
# d d d . d d d d d . P d d d d d d d d .
# d d d d . d d d d d d L d d d d d d P .
# . . P o d d d d d d d L d d d d d d . d
# . . d d d d d d d d d d o d d d d d d d
# d d P . d d d d d P m d d . d . d d d d
# d d d . . . d d P . d L L . . d d d d d
# L d d P . d d d . d l P . P . d d d d d
# . d d d . d d d d d d L . l d d d d d d
# L d d d d d L d d d d d P m L d d d d d
# d d d d d d o d o d d L d . L d d d d d
# d d d d d . P . d d d d l L L L d d d d
# d o . d . . m . d d d d l L L l . d d m
# d d d . o o . . d d d d d L L . . . . .
#
# Day: 0 Time: Day (Tick: 9)
# Entities: 373 (Plants: 352, Pauvres: 16, Malheureux: 5)
# L L l d d P l L o L . . . . . d l . d o
# L L L l d . . o L . . . . o o . d . d L
# L L . d d d d d d . . . . . . . P d l d
# L L d d d d d d . . . P . . . P d L d L
# l l . . d d d d d . . . m d d d . o d d
# L L . . d d d d d d . d l L d d P d d d
# d d d d . d d d d . d d d d d d d d d d
# d d d . d d d d d . . d d d d d d P d .
# d d d d . d d d d d d P d d d d d d . .
# . . . P d d d d d d d L d d d d d d . d
# . . P d d d d d d d d d o d d d d d d d
# d d . . d d d d d . m d d . d . d d d d
# d d d . . . d d P . d L L . l d d d d d
# L d d . . d d d P d L . . P l d d d d d
# . d d d P d d d d d d P . L d d d d d d
# L d d d d d L d d d d d . m L d d d d d
# d d d d d d o d o d d L d P L l d d d d
# d d d d d . . . d d d d L L L L d d d d
# d o . d . . m P d d d d L L L L . d d m
# d d d . o o . . d d d d d L L l . . . .
#
# Day: 0 Time: Day (Tick: 10)
# Entities: 383 (Plants: 362, Pauvres: 16, Malheureux: 5)
# L L L d d . L L o L . . . . . d L . d o
# L L L L P l . o L . l . . o o . P . d L
# L L l d d d d d d . P . . . . P . l L l
# L L d d d d d d . . . . . . . . d L l L
# L L l . d d d d d . . . m d d d . P d d
# L L . . d d d d d d . d L L d d . d d d
# d d d d . d d d d . d d d d d d P d d d
# d d d . d d d d d . P d d d d d d . d .
# d d d d . d d d d d d . d d d d d d . .
# . . P . d d d d d d d L d d d d d d . d
# . . . d P d d d d d d d o d d d d d d d
# d d . . d d d d d . m d d . d . d d d d
# d d d . . . d d P P d L L P L d d d d d
# L d d . P d d d . d L l l . L d d d d d
# l d d d . d d d d d d . l L l d d d d d
# L d d d d d L d d d d d P m L d d d d d
# d d d d d d o d o d d L d . L L d d d d
# d d d d d . . P d d d d L P L L d d d d
# d o . d . . m . d d d d L L L L . d d m
# d d d . o o . . d d d d d L L L l . . .
#
# Day: 0 Time: Day (Tick: 11)
# Entities: 385 (Plants: 364, Pauvres: 16, Malheureux: 5)
# L L L d d l L L o L . . . . . d . . d o
# L L . L . L l l L . L . . o o P . . l L
# L L L P d d d d d . P . . . . . . L L L
# L L d d d d d d . . . . . . . P d . L L
# L L L . d d d d d . . . m d d d P . d d
# L L . . d d d d d d . d L L d d . d d d
# d d d d . d d d d . d d d l l d . d d d
# d d d . d d d d d P . d d d d d d P d .
# d d d d . d d d d d d l d d d d d d . .
# . P . . d d d d d d d L d d d d d d . d
# . . . d . d d d d d d d o d d d d d d d
# d d . . d P d d d . m d d l d l d d d d
# d d d . . . d d . . l . L . L d d d d d
# L l d P . d d P P d L L P l L d d d d d
# L d d d . d d d d d d . L L L d d d d d
# L d d d d d L d d d d l P m L d d d d d
# d d d d d d o d o d d L d l L L d d d d
# d d d d d . P . d d d . L . L L d d d d
# d o . d . . m . d d d l P L L L . d d m
# d d d . o o . . d d d d d L L L L . . .
#
# Day: 0 Time: Evening (Tick: 12)
# Entities: 416 (Plants: 395, Pauvres: 16, Malheureux: 5)
# l l l D D l l l o l . . . . . D . . D d
# l l P l d l l l l d l . . o o . d d l l
# l l l . D D d D D P . . . . d P P l l l
# l l D D D D D D . . . . . . . . D . l l
# l l l d D D d D D . . . . D D D . . D D
# l l . d D D D d D D . M l l D D P D D D
# D D D D d D D D D d D D D l l D d D D D
# D D D d D D D D d P d D D D D D D . P .
# D D D D . D D D D d D l D D D D D D d .
# . . P d D D D D D D D l D D D d D D d D
# . d d D . D d D . d D D o D D D D d D D
# D D . . D P D d d M . d D l D l D D D D
# D D D P d . D D d d . d l d l D D D D D
# l l D . d D D . . P l l . l l d D D D D
# l d D d d D P D d D D P l l l . D D D D
# l D D D D D . d D D D l . . M d d D D D
# D D D d D P d D d d D l D P l l d D D D
# D D D D . d . d D D D d l . l l D D . D
# D o d D d M . d D D D l . P l l . D D M
# D D D d o o . d D D D D D l l l l d . .
#
# Day: 0 Time: Evening (Tick: 13)
# Entities: 451 (Plants: 430, Pauvres: 16, Malheureux: 5)
# l l l D D l l l o l . . . . . D d . D D
# l l . P d l l l P D l . . o o P d d l l
# l l l . D D d D D . d . . . D . . l l l
# l l D D D D D D d d . . . d P d D d l l
# l l l D D D d D D . M . d D D D d d D D
# l l . D D D D D D D d . l l D P . D D D
# D D D D D D D D D D D D D d l D D D D D
# D D D d D D D D P . D D D D D D D d P d
# D D D D d D D D D D D d D D D D D D d d
# d d . P D D D D D D D l D D D D D D d D
# d D D D d D D D d d D D d D D D D D D D
# D D . d D . D d D M d D D l D l D D D D
# D D D . P d D D D D d d l D l D D D D D
# l l D P D D D d d P l l . l l D D D D D
# l D D D D D . D d D D . l l l d D D D D
# l D D D D D P D D D D l P d M D D D D D
# D D D d D . D D d D D d D . l d D D D D
# D D D D . D P d D D D D l P l l D D . D
# D o D D D . d D D D D d P . l l d D D .
# D D D D o M . D D D D D D l l l l D d M
#
# Day: 0 Time: Evening (Tick: 14)
# Entities: 472 (Plants: 451, Pauvres: 16, Malheureux: 5)
# l l l P D d l l o l d . . . . D D d D D
# l l . . d d d l . P l . . o o . P d l l
# l l l d D D D D D . D . . d D P d d l l
# l l D D D D D D D D d . . D . D D D d l
# l l l D D D D D D d . . D D D D D D D D
# l d . D D D D D D D M d d l D . d D D D
# D D D D D D D D D D D D D D d P D D D D
# D D D D D D D D P d D D D D D D D d . D
# D D D D D D D D D D D D D D D D D P D D
# D D d . D D D D D D D d D D D D D D D D
# D D D D P D D D d d D D D D D D D D D D
# D D d d D d D D D M D D D l D d D D D D
# D D D d . D D D D D D d l D l D D D D D
# l l D . D P D D D . P l . l l D D D D D
# l D D D P D . D D D D d l l d D D D D D
# d D D D D D . P D D D P . D . D D D D D
# D D D D D d D D D D D D D M P D D D D D
# D D D D d D . D D D D D l . l l D D d D
# D o D D D d P D D D D D . . l l D D D M
# D D D D d . M D D D D P D l l l l D D .
#
# Day: 0 Time: Evening (Tick: 15)
# Entities: 493 (Plants: 472, Pauvres: 16, Malheureux: 5)
# l l l . D D l l P l D . . . . D D D D D
# l l P . D D D d . . l . d o d d . d d l
# l l l D D D D D D d D d d D P P d D l l
# l l D D D D D D D D D d . D d D D D d l
# l l d D D D D D D D d d D D D D D D D D
# l D d D D D D D D D M D D d D d D D D D
# D D D D D D D D D D D D D D D . D D D D
# D D D D D D D D P D D D D D D D P D d D
# D D D D D D D D D D D D D D D D D . D D
# D D D d D D D D D D D D D D D D D P D D
# D D D D P D D D D M D D D D D D D D D D
# D D D d D D D D D . D D D l D D D D D D
# D D D d P D D D D D D D l D d D D D D D
# d l D d D . D D D d . l . l l D D D D D
# l D D D P D d D D D P D P d D D D D D D
# D D D D D D d P D D D . M D d D D D D D
# D D D D D D D D D D D D D P . D D D D D
# D D D D D D d D D D D D d . l d D D M D
# D d D D D P . D D D D D P . l l D D D .
# D D D D D d M D D D D . D l l l l D D .
#
# Day: 0 Time: Evening (Tick: 16)
# Entities: 512 (Plants: 490, Pauvres: 17, Malheureux: 5)
# l l l P D D d d . l D d . d . D D D D D
# l l . d D D D D d P l d D d D d d d D d
# l l l D D D D D D d D D D D P P D D d d
# l l D D D D D D D D D D d D d D D D D d
# l l D D D D D D D D D D D D D D D D D D
# d D D D D D D D D D M D D D D D D D D D
# D D D D D D D D D D D D D D D d D D D D
# D D D D D D D D . P D D D D D D P D D D
# D D D D D D D D D D D D D D D D P d D D
# D D D D P D D D D D D D D D D D D P D D
# D D D D . D D D D . D D D D D D D D D D
# D D D d D D D D D d M D D l D D D D D D
# D D D d . D D D D D D D l D D D D D D D
# D d D D D P D D D D d d d l l D D D D D
# l D D D P D d D D D P D P D D D D D D D
# D D D D D D P . D D D d M D D D D D D D
# D D D D D D D D D D D D P . d D D D D D
# D D D D D D d D D D D D P . l D D D . M
# D D D D D M P D D D D D . d l l D D D d
# D D D D D D . D D D D . D l l l l D D .
#
# Day: 0 Time: Evening (Tick: 17)
# Entities: 523 (Plants: 501, Pauvres: 17, Malheureux: 5)
# l l l P D D D D d l D D d D d D D D D D
# l l d D D D D D D . d D D D P D d D D d
# l l l D D D D D D P D D D D . . D D D D
# l l D D D D D D D D D D d P d D D D D D
# l d D D D D D D D D D D D D D D D D D D
# D D D D D D D D D D . D D D D D D D D D
# D D D D D D D D P D M D D D D d D D D D
# D D D D D D D D d . D D D D D D . D D D
# D D D D D D D D D D D D D D D P . P D D
# D D D D P D D D D D D D D D D D P . D D
# D D D D d D D D D d M D D D D D D D D D
# D D D d D D D D D d . D D d D D D D D D
# D D D d P D D D D D D D d D D D D D D D
# D D D D D . D D D P D D D d d D D D D D
# d D D D . D d D D D . D . D D D D D D D
# D D D D D P . d D D D D P M D D D D D D
# D D D D D D P D D D D D . d D D D D M D
# D D D D D D d D D D D D P . l D D D d .
# D D D D D M . D D D D D P D l l D D D D
# D D D D D P . D D D D . D l l l l D D .
#
# Day: 0 Time: Night (Tick: 18)
# Entities: 525 (Plants: 503, Pauvres: 17, Malheureux: 5)
# l l l p d d d d d l d d d d d d d d d d
# l l d d d d d d d . d d d d p d d d d d
# l l l d d d d d d p d d d d . . d d d d
# l l d d d d d d d d d d d p d d d d d d
# l d d d d d d d d d d d d d d d d d d d
# d d d d d d d d d d . d d d d d d d d d
# d d d d d d d d p d m d d d d d d d d d
# d d d d d d d d d . d d d d d d . d d d
# d d d d d d d d d d d d d d d p . p d d
# d d d d p d d d d d d d d d d d p . d d
# d d d d o d d d d d m d d d d d d d d d
# d d d d d d d d d d . d d d d d d d d d
# d d d d p d d d d d d d d d d d d d d d
# d d d d d . d d d p d d d d d d d d d d
# d d d d . d d d d d . d . d d d d d d d
# d d d d d p . d d d d d p m d d d d d d
# d d d d d d p d d d d d o d d d d d m d
# d d d d d d d d d d d d p . l d d d d .
# d d d d d m o d d d d d p d l l d d d d
# d d d d d p . d d d d . d l l l l d d .
#
# Day: 0 Time: Night (Tick: 19)
# Entities: 526 (Plants: 504, Pauvres: 17, Malheureux: 5)
# l l l p d d d d d l d d d d d d d d d d
# l l d d d d d d d . d d d d p d d d d d
# l l l d d d d d d p d d d d . . d d d d
# l l d d d d d d d d d d d p d d d d d d
# l d d d d d d d d d d d d d d d d d d d
# d d d d d d d d d d . d d d d d d d d d
# d d d d d d d d p d m d d d d d d d d d
# d d d d d d d d d . d d d d d d . d d d
# d d d d d d d d d d d d d d d p . p d d
# d d d d p d d d d d d d d d d d p . d d
# d d d d O d d d d d m d d d d d d d d d
# d d d d d d d d d d . d d d d d d d d d
# d d d d p d d d d d d d d d d d d d d d
# d d d d d . d d d p d d d d d d d d d d
# d d d d . d d d d d . d . d d d d d d d
# d d d d d p . d d d d d p m d d d d d d
# d d d d d d p d d d d d O d d d d d m d
# d d d d d d d d d d d d p o l d d d d .
# d d d d d m O d d d d d p d l l d d d d
# d d d d d p . d d d d . d l l l l d d .
#
# Day: 0 Time: Night (Tick: 20)
# Entities: 528 (Plants: 505, Pauvres: 18, Malheureux: 5)
# l l l p d d d d d l d d d d d d d d d d
# l l d d d d d d o . d d d d p d d d d d
# l l l d d d d d d p d d d d . . d d d d
# l l d d d d d d d d d d d p d d d d d d
# l d d d d d d d d d d d d d d d o d d d
# d d d d d d d d d d . d d d d d d d d d
# d d d d d d d d p d m d d d d d d d d d
# d d d d d d d d d . d d d d d d . d d d
# d d d d d d d d d d d d d d d p . p d d
# d d d d p d d d d d d d d d d d p . d d
# d d d d O d d d d d m d d d d d d d d d
# d d d d d d d d d d . d d d d d d d d d
# d d d d p d d d d d d d d d d d d d d d
# d d d d d . d d d p d d d d d d d d d d
# d d d d . d d d d d . d o d d d d d d d
# d d d d d p P d d d d d p m d d d d d d
# d d d d d d p d d d d d O d d d d d m d
# d d d d d d d d d d d d p O l d d d d .
# d d d d d m O d d d d d p d l l d d d d
# d d d d d p . d d d d . d l l l l d d .
#
# Day: 0 Time: Night (Tick: 21)
# Entities: 530 (Plants: 507, Pauvres: 18, Malheureux: 5)
# l l l p d d d d d l d d d d d d d d d d
# l l d d d d d d O o d d d d p d d d d d
# l l l d d d d d d p d d d d . . d d d d
# l l d d d d d d d d d d d p d d d d d d
# l d d d d d d d d d d d d d d d O d d d
# d d d d d d d d d d . d d d d d d d d d
# d d d d d d d d p d m d d d d d d d d d
# d d d d d d d d d . d d d d d d . d d d
# d d d d d d d d d d d d d d d p . p d d
# d d d d p d d d d d d d d d d d p . d d
# d d d d O d d d d d m d d d d d d d d d
# d d d d d o d d d d . d d d d d d d d d
# d d d d p d d d d d d d d d d d d d d d
# d d d d d . d d d p d d d d d d d d d d
# d d d d . d d d d d . d O d d d d d d d
# d d d d d p p d d d d d p m d d d d d d
# d d d d d d p d d d d o O d d d d d m d
# d d d d d d d o d d d d p O l d d d d .
# d d d d d m O d d d d d p d l l d d d d
# d d d d d p o d d d d . d l l l l d d .
#
# Day: 0 Time: Night (Tick: 22)
# Entities: 531 (Plants: 508, Pauvres: 18, Malheureux: 5)
# l l l p d d d d d o d d d d d d d d d d
# l l d d d d d o O O d d d d p d d d d d
# l l l d d d d d d p d d d d . . d d d d
# l l d d d d d d d d d d d p d d d d o d
# l d d d d d d d d d d d d d d d O d d d
# d d d d d d d d d d . d d d d d d d d d
# d d d d d d d d p d m d d d d d d d d d
# d d d d d d d d d . d d d d d d . d d d
# d d d d d d d d d d d d d d d p . p d d
# d d d o p d d d d d d d d d d d p . d d
# d d d d O d d d d d m d d d d d d d d d
# d d d d d O d d d d . d d d d d d d d d
# d d d d p d d d d d d d d d d d d d d d
# d d d d d o d d d p d d d d d d d d d d
# d d d d . d d d d d . d O d d d d d d d
# d d d d d p p d d d d d p m d d d d d d
# d d d d d d p d d d d O O d d d d d m d
# d d d d d d d O d d d d p O l d d d d .
# d d d d d m O d d d d d p d l l d d d d
# d d d d d p O d d d d . d l l l l d d .
#
# Day: 0 Time: Night (Tick: 23)
# Entities: 531 (Plants: 508, Pauvres: 18, Malheureux: 5)
# l l l p d d d d d O d d d d d d d d d d
# l l d d d d d O O O d d d d p d d d d d
# l l l d d d d d d p d d d d . . o d d d
# l l d d d d d d d d d d d p d d d d O d
# l d d d d d d d d d d d d d d d O d d d
# d d d d d d d d d d . d d d d d d d d d
# d d d d d d d d p d m d d d d d d d d d
# d d d d d d d d d . d d d d d d . d d d
# d d d d d d d d d d d d d d d p . p d d
# d d d O p d d d d d d d d d d d p . d d
# d d d o O d d d d d m d d d d d d d d d
# d d d o d O d d d d . d d d d d d d d d
# d d d d p d d d d d d d d d d d d d d d
# d d d d d O d d d p d d d d d d d d d d
# d d d d . d d d d d . o O d d d d d d d
# d d d d d p p d d d d d p m d d d d d d
# d d d d d d p d d d d O O d d d d d m d
# d d d d d d d O d d d d p O l d d d d .
# d d d d d m O d d d d d p d l l d d d d
# d d d d d p O d d d d . d l l l l d d .
#
# Day: 1 Time: Morning (Tick: 24)
# Entities: 536 (Plants: 513, Pauvres: 18, Malheureux: 5)
# l l d . D D d d D o D D D D D D D D D D
# l l D d P d d o o o D D D P . d d D d D
# l l d D D D d D P . D D D D d d d d d D
# l l D D D D D D D D D D d . d d D D o D
# l D D D D D D D D D d d D P D D o d D D
# D D d D D D D D P . d D d D D d d D D D
# D D D D D D D D . D M D D D D D D D D D
# D D D D D D D D D d d d D D P D d D d D
# D D D P D D D d D D D d D D D P d P D D
# D D d o . D D D D D D d D D D D . d d D
# D D d o o D D D d . . D D D D D D d D D
# D D d o D o D d D D M D D d D d D D D D
# D D D d P d d D P D d d D D D D D D D D
# D d D d D o D D d . D D D D D D D d D D
# D D D D . D D D D D d o P D D D D D D D
# D D D D D P . d D D D d . M D D D . D D
# D D D d D D P D d D D o o P d D D D M D
# D D D D . P d o D D D P . o d D D D D d
# D D D D D M P D D D D D . D l d D D D D
# D D D D D . o D D D D . D d l l d D D d
#
# Day: 1 Time: Morning (Tick: 25)
# Entities: 553 (Plants: 530, Pauvres: 18, Malheureux: 5)
# l l D d D P D D D o D D P D D D D D D D
# l l D D . d D o o o D D D . d D D D d D
# l d D D D D D D P d D D D D D d d D d D
# l l D D D D D D D D D D D d P d D D o D
# d D D D D D D D D D D D D . D D o d D D
# D D D D D D D D P M d D d D D d d D D D
# D D D D D D D D d D . D D D D D D D D D
# D D D P D D D D D D D D D D . D d D d D
# D D D . D D D d D D D D D P P . d . D D
# D D d o d D D D D D D d D D D D P d d D
# D D D d o D D D D d . M D D D D D D D D
# D D d d D o D d D D . D D D D d D D D D
# D D D d . d d D P D D D D D D D D D D D
# D d D P D o D D d d D D D D D D D d D D
# D D D D d D D D D D D o . D D D D D D D
# D D D D D . P d D D D D P M D D D . D D
# D D D D D D P D D D D o o P D D D D . D
# D D D D d M P d D D D P d o d D D D D M
# D D D D D P . D D D D D d D d D D D D D
# D D D D D d o D D D D d D D l d D D D D
#
# Day: 1 Time: Morning (Tick: 26)
# Entities: 566 (Plants: 543, Pauvres: 18, Malheureux: 5)
# l l D D D . P D D o D P . D D D D D D D
# l l D D d D D o d o D D D d d D D D d D
# l D D D D D D D . P D D D D D d d D D D
# l d D D D D D D D D D D D d . P D D d D
# D D D D D D D D D D D D D d D D d d D D
# D D D D D D D P . . D D D D D d d D D D
# D D D D P D D D M D d D D D D D D D D D
# D D D . D D D D D D D D D D . D D D d D
# D D D d D D D D D D D D D P . d D d D D
# D D D d D D D D D D D D D D P D . d D D
# D D D D d D D D D d d . M D D D D P D D
# D D D D D d D D D P d D D D D D D D D D
# D D D P d D d D . D D D D D D D D D D D
# D D D . D d D D d d D D D D D D D D D D
# D D D D d D D D D D D d M D D D D D D D
# D D D D D P . D D D D D . . D D D . D D
# D D D D D D P D D D D P d P D D D D d D
# D D D D M . P D D D P . D d D D D D D .
# D D D D D . P D D D D D D D D D D D D M
# D D D D D d d D D D D D D D l D D D D D
#
# Day: 1 Time: Morning (Tick: 27)
# Entities: 585 (Plants: 562, Pauvres: 18, Malheureux: 5)
# l l D D D d . P D d D P d D D D D D D D
# l l D D d D D d D o D D D d d D D D d D
# l D D D D D D D P . D D D D D D P D D D
# l D D D D D D D D D D D D d d . D D D D
# D D D D D D D D D D D D D d D D d D D D
# D D D D D D P . d d D D D D D D D D D D
# D D D D P D D D M D d D D D D D D D D D
# D D D d D D D D D D D D D D P D D D d D
# D D D D D D D D D D D D D . d D D d D D
# D D D d D D D D D D D D D M . D d d P D
# D D D D D D D D D d D d . P D D D . D D
# D D D D D D D D D P d D D D D D D D D D
# D D D . P D D D d D D D D D D D D D D D
# D D D d D d D D d d D D M D D D D D D D
# D D D D D D D D D D D D . D D D D D D D
# D D D D D P d D D D D D d d D D D d D D
# D D D D D M P D D D D P D . D D D D d D
# D D D D . d . D D D . d P D D D D D D M
# D D D D D P P D D D P D D D D D D D D .
# D D D D D D D D D D D D D D l D D D D D
#
# Day: 1 Time: Morning (Tick: 28)
# Entities: 596 (Plants: 573, Pauvres: 18, Malheureux: 5)
# l l D D D d d P D D D P D D D D D D D D
# l d D D d D D D D d D D D d D D D D D D
# l D D D D D D D P d D D D D D D . D D D
# l D D D D D D D D D D D D D d P D D D D
# D D D D D D D D D D D D D d D D D D D D
# D D D P D P . M D d D D D D D D D D D D
# D D D D . D D D . D d D D D D D D D D D
# D D D D D D D D D D D D D D . P D D D D
# D D D D D D D D D D D D D d D D D d D D
# D D D d D D D D D D D D D M d D d d . D
# D D D D D D D D D D D d P . D D D d P D
# D D D D D D D D D P d D D D D D D D D D
# D D D d . D D D d D D D D D D D D D D D
# D D D d P D D D d d D D M D D D D D D D
# D D D D P D D D D D D D d D D D D D D D
# D D D D D . d D D D D D D D D D D D D D
# D D D D D M . D D D P P D d D D D D D D
# D D D D . P P D D D P D . D D D D D D .
# D D D D D . P D D D . D D D D D D D D M
# D D D D D D D D D D D D D D l D D D D D
#
# Day: 1 Time: Morning (Tick: 29)
# Entities: 611 (Plants: 588, Pauvres: 18, Malheureux: 5)
# l l D D D D D P D D D . D D D D D D D D
# l D D D d D D P D d D D P D D D D D D D
# d D D D D D D D . d D D D D D P d D D D
# l D D D D D D D D D D D D D D . D D D D
# D D D D D D D D D D D D D d D D D D D D
# D D D . D P d . D D D D D D D D D D D D
# D D D D P D M D d D d D D D D D D D D D
# D D D D D D D D D D D D D D d . D D D D
# D D D D D D D D D D D D D d P D D d D D
# D D D d D D D D D D D D D . d D d d d D
# D D D D D D D D D D D P M d D D D D P D
# D D D D D D D D D . D D D D D D D D D D
# D D D d d D D D d P D D D D D D D D D D
# D D D P . D D D d d D D M D D D D D D D
# D D D D . D D D D D D D d D D D D D D D
# D D D D P d d D D D D D D D D D D D D D
# D D D D P M d D D D . P D d D D D D D D
# D D D D d . . D D D P D d D D D D D D d
# D D D D D d P D D D P D D D D D D D D M
# D D D D D D P D D D D D D D d D D D D D
#
# Day: 1 Time: Day (Tick: 30)
# Entities: 612 (Plants: 589, Pauvres: 18, Malheureux: 5)
# L L d d d d d P d d d P d d d d d d d d
# L d d d d d d . d d d d . d d d d d d d
# d d d d d d P d l d d d d d d P d d d d
# L d d d d d d d d d d d d d d . d d d d
# d d d d d d d d d d d d d d d d d d d d
# d d d . d P d . d d d d d d d d d d d d
# d d d d . d m d d d d d d d d d d d d d
# d d d d d P d d d d d d d d d P d d d d
# d d d d d d d d d d d d d d . d d d d d
# d d d d d d d d d d d d d . d d d d d d
# d d d d d d d d d d d P m d d d d d . d
# d d d d d d d d d . d d d d d d d d P d
# d d d d d d d d d . d d d d d d d d d d
# d d d . P d d d P d d d m d d d d d d d
# d d d d P d d d d d d d d d d d d d d d
# d d d d . P d d d d d P d d d d d d d d
# d d d d . m d d d d . . d d d d d d d d
# d d d d d . . P d d P d l d d d d d d d
# d d d d d d . d d P . d d d d d d d d m
# d d d d d d P d d d d d d d d d d d d d
#
# Day: 1 Time: Day (Tick: 31)
# Entities: 611 (Plants: 588, Pauvres: 18, Malheureux: 5)
# L L d d d d d P d d P . d d d d d d d d
# L d d d d d P . d d d d . d d d d d d d
# d d d d d d . d L d d d d d d . d d d d
# L d d d d d d d d d d d d d d P d d d d
# d d d d d d d d d d d d d d d d d d d d
# d d d . d . d . d d d d d d d d d d d d
# d d d d P d m d d d d d d d d d P d d d
# d d d d d . d d d d d d d d d . d d d d
# d d d d d d P d d d d d d d . d d d d d
# d d d d d d d d d d d d d . d d d d d d
# d d d d d d d d d d d P m d d d d d . d
# d d d d d d d d d . d d d d d d d d . d
# d d d d d d d d d P d d d d d d d P d d
# d d d . . d d d . d d d m d d d d d d d
# d d d d P d d d d d . P l l d d d d d d
# d d d P . . d d d d d . d d d d d d d d
# d d d d P m d P d d . . d d d d d d d d
# d d d d d . . . d d P d L d l d d d d d
# d d d d d d P d d . P d d d d d d d d m
# d d d d d d . d d d d d d d d d d d d d
#
# Day: 1 Time: Day (Tick: 32)
# Entities: 611 (Plants: 588, Pauvres: 18, Malheureux: 5)
# L L d d d d d . P d P . d d d d d d d d
# L d d d d d . . d d d d . d d d d d d d
# d d d d d d P d L d d d d d d P d d l d
# L d d d d d d d d d d d d d d . d d d d
# d d d d d d d d d d d d d d d d d d d d
# d d d . d P d . d d d d d d d d d d d d
# d d d d . d m d d d d d d d d d . d d d
# d d d d d . d d d d d d d d d . P d d d
# d d d d d d . d d d d d d d . d d d d d
# d d d d d d d P d d d d d . d d d d d d
# d d d d d d d d d d d P m d d d d d . d
# d d d d d d d d d . d d d d d d P d . d
# d d d d d d d d d P d d l d d d d . d d
# d d d P . d d d . d d l m d d d d d d d
# d d d d . d d d d d . . P L d d d d d d
# d d d . P . d d d d d . l l d d d d d d
# d d d P . m d . d d . . d l d d d d d d
# d d d d d . . P d d . l L l L d d d d d
# d d d d d d . d d . P d d d d d d d d m
# d d d d d d P d d d P d d d d d d d d d
#
# Day: 1 Time: Day (Tick: 33)
# Entities: 613 (Plants: 590, Pauvres: 18, Malheureux: 5)
# L L d d d d d . . d . P d d d d d d l d
# L d d d d d P P d d d d . d P d d d d d
# d d d d d d . d L d d d d d d . d d L d
# L d d d d d d d d d d d d d d . d d d l
# d d d d d d d d d d d d d d d d d d d d
# d d d . d . d . d d d d d d d d d d d d
# d d d d P d m d d d d d d d d d P d d d
# d d d d d . d d d d d d d d d . . d d d
# d d d d d d P d d d d d d d . d d d d d
# d d d d d d d . d d d d d . d d d d d d
# d d d d d d d d d d P . m d d d d d . d
# d d d d d d d d d . d d d d d d P d . d
# d d d d d d d d d P d d L l d d d . d d
# d d d . . d d d . d . l m l d d d d d d
# d d d P . d d d d d l l . L d d d d d d
# d d d . . P d d d d d P L L d d d d d d
# d d d P . m d . d d l l l L l d d d d d
# d d d d d . . . d d . . L L L l d d d d
# d d d d d d . P d P P l l d d d d d d m
# d d d d d d P d d d . d d d d d d d d d
#
# Day: 1 Time: Day (Tick: 34)
# Entities: 614 (Plants: 591, Pauvres: 18, Malheureux: 5)
# L L d d d d d . . d . . P d d d . d L d
# L l d d d d . P d l d d . d . P d l l d
# d d d d d d P d L d d d d d d . d l L d
# L d d d d d d d d d d d d d d . d d d L
# d d d d d d d d d d d d d d d d d d d d
# d d d . d . d . d d d d d d d d d d d d
# d d d d . P m d d d d d d d d d . d d d
# d d d d d . d d d d d d d d d P . d d d
# d d d d d d P d d d d d d d . d d d d d
# d d d d d d d . d d d d d . d d d d d d
# d d d d d d d d d d . P m d d d d d . d
# d d d d d d d d d P d d d d d d P d . d
# d d d d d d d d d . d l L L l d d . d d
# d d d . . d d d . d . L m L d d d d d d
# d d d P P d d d d d L L l L d d d d d d
# d d P . . . d d d d P . L L d d d d d d
# d d d . . m d . d d L L l L L d d d d d
# d d d d d . . P d P . l L L L L d d d d
# d d d d d d P . d . . L L l l d d d d m
# d d d d d d . d P d . d d d d d d d d d
#
# Day: 1 Time: Day (Tick: 35)
# Entities: 619 (Plants: 595, Pauvres: 19, Malheureux: 5)
# L L d d d d d . l d . . . d d d l d L d
# L L d d d d P P d L d d P d . . l L L l
# d d d d d d . P L d d d d d P . d L L d
# L d d d d d d d d d d d d d d . d d d L
# d d d d d d d d d d d d d d d d d d d d
# d d d . d . d . d d d d d d d d d d d d
# d d d d . . m d d d d d d d d P . d d d
# d d d d d P d d d d d d d d d . . d d d
# d d d d d d . d d d d d d d . d d d d d
# d d d d d P d . d d d . d . d d d d d d
# d d d d d d d d d P P . m d d d d d . d
# d d d d d d d d d . d d d d d d P d . d
# d d d d d d d d d . d L L L L d d . d d
# d d d P . P d d . l l L m L d d d d d d
# d d d . . d d d d d L L L L d d d d d d
# d d . P . . d d d d . l L L l d d d d d
# d d d . . m d . d d P L L L L d d d d d
# d d d d d . P . d . . L L L L L d d d d
# d d d d d d P . d P l L L L L d d d d m
# d d d d d d . P . d . d d l d d d d d d
#
# Day: 1 Time: Evening (Tick: 36)
# Entities: 653 (Plants: 629, Pauvres: 19, Malheureux: 5)
# l l D D D d d d . D d d d D D D d d l D
# l l D d d d . . P l d d P D P d d l l l
# d D d d D D P P l d D D D D . d d l l D
# l D D D D D D D d D D D D D D d D D d l
# D D D D D D D D D D d D D d D D d d D D
# D D d d D . d d d D D D d D P d d D D D
# D D D D . . M D d D d D D D D . d D D D
# D D D d D P D D D D d D D D d . d D d D
# D D D d d D d d D D D D D D d D D d D D
# D D D d D . D d D D D P D d D d d D d D
# D d d d D P D D D . P d M d D D D d d D
# D D d d D d D d D d d D D D D d . D d d
# D D D d d d d D d d . l l l . P D d D D
# D d D . P P D D d l l M . l D D D d d D
# D D D d P D d D D D l l l l D D D D D D
# D D d . d M D d D D d d l l l d D D D D
# D D D d d . D d D D . l l l l D D D D D
# D D D D D P . d D d P l l l l l D D D d
# D d D D D d P d P . . l l l l D D . D .
# D D D D D D d . P D d D D l D D D D M D
#
# Day: 1 Time: Evening (Tick: 37)
# Entities: 675 (Plants: 651, Pauvres: 19, Malheureux: 5)
# l l D D D D D D d D D D D D D D D D l D
# l l D d D d P d P l D d . D . D D l l l
# D D D d D P . . l D D D D P P d d d l D
# l D D D D D D D D D D D D D D d D D D l
# D D D D D D D D D D d D D D D D D D D D
# D D D D D d D M d D D D d D . D D D D D
# D D D D d d . D d D d D D D D P d D D D
# D D D d D . D D D D D D D D d d d D D D
# D D D D D D P D D D D D P D d D D D D D
# D D D d D d D D D D D . D d D D d D d D
# D D d d D P D D D P . D . D D D D d d D
# D D d d D d D d D d d D M D D D d D D d
# D D D d d D d D d d d l l l d P D D D D
# D d D P . . D D d l d M . d D D D D D D
# D D D d . P P D D D l l l l D D D D D D
# D D D d d . M d D D d D d l l D D D D D
# D D D D d d P d D D d P l l d D D D D D
# D D D D D . d P D D . d l d l l D D D D
# D D D D D d . d . P d d l l l D D . D d
# D D D D D D d P . D d D D l D D D D . M
#
# Day: 1 Time: Evening (Tick: 38)
# Entities: 695 (Plants: 671, Pauvres: 19, Malheureux: 5)
# l l D D D D D D D D D D D D D D D D l D
# l l D d D d . d P d D d d D d D D d d d
# D D D D D . P P d D D D D P P d d d l D
# d D D D D D D D D D D D D D D d D D D l
# D D D D D D D D D D D D D D D D D D D D
# D D D D D D D . M D D D D D d D D D D D
# D D D D D D d D d D d D D D D P d D D D
# D D D d D d D P D D D D D D d d d D D D
# D D D D D D . D D D D D . D d D D D D D
# D D D d D D D D D D D P D D D D D D d D
# D D d D D P D D D P d D d D D D D d d D
# D D d d D d D d D d d D . D D D P D D D
# D D D d d D d D d d d l M d D . D D D D
# D D D P d P P D d l M . . D D D D D D D
# D D D d d . . D D D d d d d D D D D D D
# D D D d D d M d D D d D P d d D D D D D
# D D D D D D P d D D D . d d D D D D D D
# D D D D D P d . D D d D d D l l D D D D
# D D D D D d d d d . D d d l l D D d D D
# D D D D D D D P P D D D D d D D D D d M
#
# Day: 1 Time: Evening (Tick: 39)
# Entities: 708 (Plants: 684, Pauvres: 19, Malheureux: 5)
# l d D D D D D D D D D D D D D D D D l D
# l l D d D d P d . d D d d D d D D d d D
# D D D D D d . P d P D D P P . d d d d D
# D D D D D D D D D D D D D D D d D D D d
# D D D D D D D D D D D D D D D D D D D D
# D D D D D D D d M D D D D D d D D D D D
# D D D D D D d D d D D D D D D P d D D D
# D D D d D D D . D D D D D D D d D D D D
# D D D D D D P D D D D D d D d D D D D D
# D D D d P D D D D P D . D D D D D D d D
# D D D D D . D D D . P D d D D D P d d D
# D D d d D d D D D d D D M D D D . D D D
# D D D d d D d D d d D d . D D d D D D D
# D D D P d . . D d d M d d D D D D D D D
# D D D d P P d D D D D d d P D D D D D D
# D D D d D M . d D D d D . D d D D D D D
# D D D D D D . d D D D d d d D D D D D D
# D D D D D P d P D D D D d D d d D D D D
# D D D D D d d d d P D D d d d D D d D M
# D D D D D D D . P D D D D D D D D D D .
#
# Day: 1 Time: Evening (Tick: 40)
# Entities: 722 (Plants: 698, Pauvres: 19, Malheureux: 5)
# l D D D D D P D D D D D D D D D D D d D
# d d D d D d . d d P D D d D d D D d D D
# D D D D D d d . d . D D P . d d d d D D
# D D D D D D P D D D D D P D D d D D D D
# D D D D D D D D D D D D D D D D D D D D
# D D D D D D D d M D D D D D D D D D D D
# D D D D D D D D D D D D D D D . d D D D
# D D D D D D D d D D D D D D P d D D D D
# D D D D P D P D D D D D D D d D D D D D
# D D D D . D D D P P D d D D D D D D d D
# D D D D D d D D D d . D d D D D . D D D
# D D d d D d D D D d D D M D D D P D D D
# D D D d d D d D d d M d d D D d D D D D
# D D D P d P . D D D . D P D D D D D D D
# D D D d M . D D D D D d d . D D D D D D
# D D D P D . d d D D d D d D D D D D D D
# D D D D D D d d D D D d d d D D D D D D
# D D D D D P d . P D D D D D D D D D D D
# D D D D D d d d P . D D d D d D D d D M
# D D D D D D D d . D P D D D D D D D D d
#
# Day: 1 Time: Evening (Tick: 41)
# Entities: 737 (Plants: 713, Pauvres: 19, Malheureux: 5)
# l D D D D D . D D P D D D D D D D D D D
# D D D d D d P d D . D D P D D D D d D D
# D D D D D d d d d d D D . d D d d d D D
# D D D D D D . P D D D D . D D d D D D D
# D D D D D D D D D D D P D D D D D D D D
# D D D D D D D D . M D D D D D D D D D D
# D D D D D D D D D D D D D D D P d D D D
# D D D D D D D d D D D D D D . d D D D D
# D D D P . D P D D D D D D D d D D D D D
# D D D D d D D D P . P D D D D D D D d D
# D D D D D d D D D d d D D D D D P D D D
# D D D d D d D D D d D D . M D D . D D D
# D D D d d D d D d d . P d D D d D D D D
# D D D P M . P D D D d M . D D D D D D D
# D D P d . d D D D D D D d d D D D D D D
# D D D . D d d d D D d D d D D D D D D D
# D D D D D D d d D D D d d d D D D D D D
# D D D D D . d P P D D D D D D D D D D D
# D D D D P d d D . d D D d D D D D D D .
# D D D D D D D D d D P D D D D D D D M D
#
# Day: 1 Time: Night (Tick: 42)
# Entities: 739 (Plants: 715, Pauvres: 19, Malheureux: 5)
# l d d d d d . d d p d d d d d d d d d d
# d d d d d d p o d . d d p d d d d d d d
# d d d d d d d d d d d d o d d d d d d d
# d d d d d d . p d d d d . d d d d d d d
# d d d d d d d d d d d p d d d d d d d d
# d d d d d d d d . m d d d d d d d d d d
# d d d d d d d d d d d d d d d p d d d d
# d d d d d d d d d d d d d d . d d d d d
# d d d p . d p d d d d d d d d d d d d d
# d d d d d d d d p . p d d d d d d d d d
# d d d d d d d d d d d d d d d d p d d d
# d d d d d d d d d d d d . m d d o d d d
# d d d d d d d d d d . p d d d d d d d d
# d d d p m . p d d d d m . d d d d d d d
# d d p d . d d d d d d d d d d d d d d d
# d d d . d d d d d d d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
# d d d d d . d p p d d d d d d d d d d d
# d d d d p d o d . d d d d d d d d d d .
# d d d d d d d d d d p d d d d d d d m d
#
# Day: 1 Time: Night (Tick: 43)
# Entities: 740 (Plants: 716, Pauvres: 19, Malheureux: 5)
# l d d d d d o d d p d d d d d d d d d d
# d d d d d d p O d . d d p d d d d d d d
# d d d d d d d d d d d d O d d d d d d d
# d d d d d d . p d d d d . d d d d d d d
# d d d d d d d d d d d p d d d d d d d d
# d d d d d d d d . m d d d d d d d d d d
# d d d d d d d d d d d d d d d p d d d d
# d d d d d d d d d d d d d d . d d d d d
# d d d p . d p d d d d d d d d d d d d d
# d d d d d d d d p . p d d d d d d d d d
# d d d d d d d d d d d d d d d d p d d d
# d d d o d d d d d d d d . m d d O d d d
# d d d d d d d d d d . p d d d d d d d d
# d d d p m . p d d d d m . d d d d d d d
# d d p d . d d d d d d d d d d d d d d d
# d d d . d d d d d d d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
# d d d d d . d p p d d d d d d d d d d d
# d d d d p d O d . d d d d d d d d d d .
# d d d d d d o d d d p d d d d d d d m d
#
# Day: 1 Time: Night (Tick: 44)
# Entities: 743 (Plants: 719, Pauvres: 19, Malheureux: 5)
# l d d d d d O d d p d d d d d d d d d d
# d d d d d d p O o o d d p d d d d d d d
# d d d d d d d d d d d d O d d d d d d d
# d d d d d d . p d d d d o d d d d d d d
# d d d d d d d d d d d p d d d d d d o d
# d d d d d d d d . m d d d d d d d d d d
# d d d d d d d d d d d d d d d p d d d d
# d d d d d d d d d d d d d d . d d d d d
# d d d p . d p d d d d d d d d d d d d d
# d d d d d d d d p . p d d d d d d d d d
# d d d d d d d d d d d d d d d d p d d d
# d d d O d d d d d d d d . m d d O d d d
# d d d d o d d d d d . p d d d d d d d d
# d d d p m o p d d d d m . d d d d d d d
# d d p d . d d d d d d d d d d d d d d d
# d d d . d d d d d d d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
# d d d d d . d p p d d d d d d d d d d d
# d d d d p d O d . d d d d d d d d d d .
# d d d d d d O d d d p d d d d d d d m d
#
# Day: 1 Time: Night (Tick: 45)
# Entities: 744 (Plants: 720, Pauvres: 19, Malheureux: 5)
# l d d d d d O o d p d d d d d d d d d d
# d d d d d d p O O O d d p d d d d d d d
# d d d d d d d d d d d d O d d d d d o d
# d d d d d d . p d d d d O d d d d d d d
# d d d d d d d d d d d p d d d d d d O d
# d d d d d d d d . m d d d d d d d d d d
# d d d d d d d d d d d d d d d p d d d d
# d d d d d d d d d d d d d d . d d d d d
# d d d p . d p d d d d d d d d d d d d d
# d d d d d d d d p . p d d d d d d d d d
# d d d d d d d d d d d d d d d o p d d d
# d d d O d d d d d d d d . m d d O d d d
# d d d o O d d d d d . p d d d d d d d d
# d d d p m O p d d d d m . d d d d d d d
# d d p d . d d d d d d d d d d d d d d d
# d d d . d d d d d d d d o d d d d d d d
# d d d d d d d d d d d o d d d d d d d d
# d d d d d o d p p d d d d d d d d d d d
# d d d d p o O o . d d d d d d d d d d .
# d d d d d d O d d d p d d d d d d d m d
#
# Day: 1 Time: Night (Tick: 46)
# Entities: 744 (Plants: 720, Pauvres: 19, Malheureux: 5)
# l d d d d d O O d p d d d d d d d d d d
# d d d d d o p O O O d d p d d d d d d d
# d d d d d d o d d d d d O o d d d d O d
# d d d d d d . p d d d d O d d d o d d d
# d d d d d d d d d d d p d d d d d d O d
# d d d d d d d d . m d d d d d d d d d d
# d d d d d d d d d d d d d d d p d d d d
# d d d d d d d d d d d d d d . d d d d d
# d d d p . d p d d d d d d d d d d d d d
# d d d d d d d d p . p d d d d d d d d d
# d d o o d d d d d d d d d d d O p d d d
# d d o O o d d d d d d d . m d d O d d d
# d d d O O d d d d d . p d d d d d d d d
# d d d p m O p d d d d m . d d d d d d d
# d d p d . d d d d d o d d d d d d d d d
# d d d . d d d d d d d d O d d d d d d d
# d d d d d d d d d d d O o d d d d d d d
# d d d d d O d p p d d d d d d d d d d d
# d d d d p O O O . d d d d d d d d d d .
# d d d d d d O d d d p d d d d d d d m d
#
# Day: 1 Time: Night (Tick: 47)
# Entities: 745 (Plants: 721, Pauvres: 19, Malheureux: 5)
# l d d d d d O O d p d d d d d d d d d d
# d d d d d O p O O O d d p d d d d d d d
# d d d d d d O d d d d d O O d d d d O d
# d d d d d d o p d d d d O d d d O d o d
# d d d d d d d d d d d p d d d d o d O d
# d d d d d d d d . m d d d d d d d d d d
# d d d d d d d d d d d d d d d p d d d d
# d d d d d d d d d d d d d d . d d d d d
# d d d p . d p d d d d d d d d d d d d d
# d d d d o d d d p . p d d d d d d d d d
# d d O O d d d d d d d d d d d O p d d d
# d d O O O d d d d d d d . m d d O d d d
# d d d O O o d d d d . p d d d d d d d d
# d d d p m O p d d d o m . d d d d d d d
# d d p d . d d d d d O o d d d d d d d d
# d d d . d d d d d d o o O d d d d d d d
# d d d d d d d d d d d O O d d d d d d d
# d d d d d O o p p d d o o d d d d d d d
# d d d d p O O O . d d d d d d d d d d .
# d d d d d o O d d d p d d d d d d d m d
#
# Day: 2 Time: Morning (Tick: 48)
# Entities: 750 (Plants: 726, Pauvres: 19, Malheureux: 5)
# l D D D D D P o d P D D D D D D D D D D
# D d D d d o . o o o d D P d d D d d D d
# D D D d D d o P d D D d o o d d d d o D
# D D D D D D d . D D D d o d d D o d o d
# D D D D D D D D . D d P d d D D d d o D
# D D d D D D D d d M D D d D D d d D D D
# D D D D d D d D d D d D D D d . D d D D
# D D D d D P D D d D d D D D d P d d D D
# D D D P d D . D D P D D d d D D d d D D
# D D d d o d D D . . . d d d d d D D d D
# D D o o d D d D P d d D d d d P . D d D
# D d o o o D D D D . d D d . D d o d D D
# D D D . o d D D d d M . D . M d d D D D
# D D D P M o . d d d o P d D D D D D D D
# D P . D d d P D d D o o d d D D D D D D
# D D D d d d d d D d o o o d d D D D D D
# D D D D d d d d D D d o o D d d D D D D
# D D D D d o d . P d d d d D d D D D d D
# D D D D . o o o P d P D D d D D D . D d
# D D D D D P o d d D . D D D D D D D M D
#
# Day: 2 Time: Morning (Tick: 49)
# Entities: 769 (Plants: 745, Pauvres: 19, Malheureux: 5)
# d D D D D D P o d . P P D D D D D D D D
# D d D D d o d o o o D D . d d D d d D D
# D D D d D d d . P D D d o o d d d d d D
# D D D D D D d . D D D D o D d D o D o D
# D D D D D D D D d M D . P d D D d D o D
# D D d D D D D D d . D D D D D d d D D D
# D D D D d D d D d D d D D D d d D D D D
# D D D d D . D D d D d D D D D P D D D D
# D D D P P D d D P . D D D d D D d d D D
# D D D D o d D D d d d d d D D d D D d D
# D D o d D D D D . d d D d D P . d D d D
# D d o o o D D D P d M D d M D d o d D D
# D D D d o D D D d d . d P d . D D D D D
# D D D P . d d d d d d . D D D D D D D D
# D . P D d M . P D D o d d d D D D D D D
# D D D d d d d D D d d d o D D D D D D D
# D D D D d d d d D D D o o D d D D D D D
# D D D D d d d d P D d P D D D D D D d D
# D D D D d o d o . d . D D D D D D d D D
# D D D D D P o d P D d D D D D D D D M D
#
# Day: 2 Time: Morning (Tick: 50)
# Entities: 786 (Plants: 762, Pauvres: 19, Malheureux: 5)
# D D D D D D P d D P . P D D D D D D D D
# D D D D D d d d d d D D d d d D d d D D
# D D D d D d d P . D D d d d d d d d D D
# D D D D D D D d D D D D d D d D d D d D
# D D D D D D D D d . D d P d D D d D o D
# D D D D D D D D d d M D D D D D d D D D
# D D D D d D d D d D D D D D d P D D D D
# D D D D D P D P d D d D D D D . D D D D
# D D D . . D d D . d D D D d D D d d D D
# D D D P d d D D d d d d d D D d D D D D
# D D d d D D D D d d d D M D P d d D D D
# D D d d d D D P . d M D P . D D d d D D
# D D D d d D D D d d d D . d d D D D D D
# D D D P d d d d D d D d D D D D D D D D
# D d . D d . d P D D d D d d D D D D D D
# D D D P d M d D D D D d o D D D D D D D
# D D D D d d d d D D D d d D D D D D D D
# D D D D d d d d P D d . D D D D D D d D
# D D D D d d d d P d . P D D D D D D D D
# D D D D P . d D . D d D D D D D D D M D
#
# Day: 2 Time: Morning (Tick: 51)
# Entities: 802 (Plants: 778, Pauvres: 19, Malheureux: 5)
# D D D D D D P D P . d . P D D D D D D D
# D D D D D d D d d d D D d d d D D D D D
# D D D D D d d . P D D D d d D d d D D D
# D D D D D D D d D D D D d D d D D D d D
# D D D D D D D D d d D P . d D D d D d D
# D D D D D D D D d d M D D D D D P D D D
# D D D D d D P D d D D D D D d . D D D D
# D D D D D . D . D D d D D D D d D D D D
# D D D d d D D D P d D D D d D D d d D D
# D D D . d d D D D d d d d D D d D D D D
# D D d P D D D D P d d M . D P D d D D D
# D D D d d D D . d d . M . d D D d d D D
# D D D P d D D D d d d P d D d D D D D D
# D D D . D d D d P d D d D D D D D D D D
# D D P D M d d . D D d D d D D D D D D D
# D D D . d . d D D D D d d D D D D D D D
# D D D D d d d d D D D d d D D D D D D D
# D D D D d d d d P D d d D D D D D D d D
# D D D D d d D P . D d P D D D D D M D D
# D D D D P d d D d D D D D D D D D D . D
#
# Day: 2 Time: Morning (Tick: 52)
# Entities: 820 (Plants: 796, Pauvres: 19, Malheureux: 5)
# D D D D D D . P . d D d . P D D D D D D
# D D D D D d D P d D D D D d d D D D D D
# D D D D D d d d . D D D d d D d d D D D
# D D D D D D D d P D D D d D d D D D d D
# D D D D D D D D d D D P d d D D d D D D
# D D D D D D D D d M . D D D D D . D D D
# D D D D d D P D d D D D D D d d D P D D
# D D D D D d D d D D d D D D D d D D D D
# D D D D d D D D . d D D D D D D d d D D
# D D D d d D D D D P d d D D D d D D D D
# D D d P D D D D P d d . M D . D d D D D
# D D D d P D D d d d d P d d P D d d D D
# D D D . d D D D D d M . d D D D D D D D
# D D D d D d D d . d D d D D D D D D D D
# D D P D M d d P D D d D d D D D D D D D
# D D D d d d d D D D D d d D D D D D D D
# D D D D d d d d D D D d D D D D D D D D
# D D D D d D d d P D d d D D D D M D d D
# D D D P d d D . P D d . D D D D D . D D
# D D D D . D d D d D P D D D D D D D d D
#
# Day: 2 Time: Morning (Tick: 53)
# Entities: 836 (Plants: 812, Pauvres: 19, Malheureux: 5)
# D D D D D D d . d d D D d P D D D D D D
# D D D D D D D . P D D D D D d D D D D D
# D D D D D d d d P D D D d d D d d D D D
# D D D D D D D P . D D D d D d D D D D D
# D D D D D D D D d D D . d D D D D D D D
# D D D D D D D D D . d P D D D D d D D D
# D D D D d D P D d D M D D D d d D . P D
# D D D D D d D d D D d D D D D d D D D D
# D D D D d D D D P d D D D D D D d d D D
# D D D D P D D D D . d d D D D d D D D D
# D D d . D D D P . d D d . M d D d D D D
# D D D d . D D d d d d M d d P D d d D D
# D D D d P D D D D d . d P D D D D D D D
# D D D d D d D d d d D d D D D D D D D D
# D D P D M d d . D D D D d D D D D D D D
# D D D d d d d P D D D d D D D D D D D D
# D D D D d d d d D D D d D D D D D D D D
# D D D D d D d d P D d d D D D D . M d D
# D D D P D d D d P D d P D D D D D d D D
# D D D D d D d D D D . D D D D D D D D D
#
# Day: 2 Time: Day (Tick: 54)
# Entities: 836 (Plants: 812, Pauvres: 19, Malheureux: 5)
# d d d d d d d . d d d d d P d d d d d d
# d d d d d d d . . d d d d d d d d d d d
# d d d d d d P d . P d d d d d d d d d d
# d d d d d d d . P d d d d d d d d d d d
# d d d d d d d d d d d P d d d d d d d d
# d d d d d d d d d . d . d d d d d d d d
# d d d d d d . d d d m d d d d d d . P d
# d d d d d P d d d d l d d d d d d d d d
# d d d d d d d d . d d d d d d d d d d d
# d d d d . d d d d P d d d d d d d d d d
# d d d P d d d . . d d d . m d d d d d d
# d d d d . d d P d d d m d d P d d d d d
# d d d P . d d d d d . P . d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
# d d . d m d d . d d d d d d d d d d d d
# d d P d d d d . P d d d d d d d d d d d
# d d d d d d d d P d d l d d d d d d d d
# d d d d d d d d . d d d d d d d . m d d
# d d d P d d d d P d d . d d d d d d d d
# d d d d d d d d d d . d P d d d d d d d
#
# Day: 2 Time: Day (Tick: 55)
# ...
# D D D D D d d P d d d d d d d d d D d D
# D D D D D d d . d d d d d d d d d D D D
# D D D D d P d d d d d d d d d d D d D D
# D D D D d . d d d D d d d d d d D D D D
# D D D D D D d d d d d d D D d d d d d D
# D D D D d d D d d d d D D D d d d d D D
# D D D D d d d d d . d d d D d d d d d D
# D D d d d d D d P d d d d d d d d d d D
# D d . d d d D d d d d d d d d d d d d D
# d d P d d d d d d d d d d d d d D d d D
# D d d d d . d d d M d d d d d d d d d D
# D d d d d M P d d d d d d d d d d D d D
# D D d d . d d d P d d d d d d d d d d D
# D d d d d d d d d d d d d d d d D d d D
# D D d D d d d d . M d d d . d d d d d D
# D D D D d d d d d d d d d d P d d d d D
# D D D D d d d d d d d d d d d M d d D D
# D D D D d d d d d d M d d d D d d d d D
# D D D D D D D d d d d d d D D D d D D D
#
# Day: 7 Time: Evening (Tick: 184)
# Entities: 1635 (Plants: 1624, Pauvres: 6, Malheureux: 5)
# D D D D D d d d d d d d d d D D D D D D
# D D D D D d d . d d d d d d d d d D d D
# D D D D D d P d d d d d d d d d d D D D
# D D D D d P D d d d d d d d d d D d D D
# D D D D D d d d d D d d d D d d D D D D
# D D D D D D d D d d d d D D D d d d d D
# D D D D D d D d d d d D D D d d d d D D
# D D D D d d d d d d d d d D d d d d d D
# D D d d d d D d . d d d d d d d d d d D
# D P d d d d D P d d d d d d d d d d d D
# d d . d d d d d d M d d d d d d D d d D
# D d d d d d d d d . d d d d d d d d d D
# D d d d d M P d d d d d d d d d d D d D
# D D d d d d d d P d d d d d d d d d D D
# D d d d d d d d d d d d d d d d D D d D
# D D d D d d d d d M d d d d d d d d D D
# D D D D d d d d d d d d d P M d D d d D
# D D D D d d d d d d d d d d d . d d D D
# D D D D d d d d d M . d d d D d d d d D
# D D D D D D D d d d d d d D D D d D D D
#
# Day: 7 Time: Evening (Tick: 185)
# Entities: 1641 (Plants: 1630, Pauvres: 6, Malheureux: 5)
# D D D D D d d d d d d d d d D D D D D D
# D D D D D d d d d d d d d d d d d D D D
# D D D D D d P d d d d d d d d d d D D D
# D D D D d . D P d d d d d d d d D d D D
# D D D D D D d d d D d d d D d d D D D D
# D D D D D D d D d d d d D D D d D d D D
# D D D D D d D d d d d D D D d d d d D D
# D D D D d d d d d d d d d D D d d d d D
# D D D d d d D d d d d d d d d d d d d D
# D . P d d d P . d d d d d d d d d d d D
# d d d d d d D d M . d d d d d d D d d D
# D d d d d d d d d d d d d d d d d d d D
# D D d d d . P d d d d d d d d d d D d D
# D D d d d M d d P d d d d d d d d d D D
# D d d d d d d d d d M d d d d d D D d D
# D D d D d d d d d . d d d d P d d d D D
# D D D D d d d d d d d d d . M d D d d D
# D D D D d d d d d d d d d d d d d d D D
# D D D D d d d d d . d d d d D d d d d D
# D D D D D D D d d M d d D D D D d D D D
#
# Day: 7 Time: Night (Tick: 186)
# Entities: 1641 (Plants: 1630, Pauvres: 6, Malheureux: 5)
# d d d d d d d d d o d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
# d d d d d d p d d d d d d d d d d d d d
# d d d d d . d p d d d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
# d d d d o d d d d d d d d d d d d d d d
# d . p d d d p . d d d d d d d d d d d d
# d d d d d d d d m . d d d d d o d d d d
# d d d d d d d d d d d d d d d d d d o d
# d d d d d . p d d d d d d d d d d d d d
# d d d d d m d d P d d d d d d d d d d d
# d d d d d d o d d d m d d d d d d d d d
# d d d d d d d d d . d d d d p d d d d d
# d d d d d d d d o o d d d . m d d d d d
# d d d d d d d d d d d d d d d d d d d d
# d d d d d o o d d . d d d d d d d d d d
# d d d d d d d d d m d d d d d d d d d d
#
# Day: 7 Time: Night (Tick: 187)
# Entities: 1643 (Plants: 1632, Pauvres: 6, Malheureux: 5)
# d d d d d d d d o O d d d d d d d d d d
# d d d d d d d o o d d d d d d d d d d d
# d d d d d d p d d d d d d d d d o d d d
# d d d d d . d p d d d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
# d d d d O d d d d d d d d d d d d d d d
# d . p d d d p . d d d d d d d o o d d d
# d d d d o o d d m . d d d d o O d d d d
# d d d d d d d d d d d d d o d d d d O d
# d d d d d o p d d d d d d d d d d o d d
# d d d d d m d d P d d d d d d d d d d d
# d d d d d d O d d d m d d d d d d d d d
# d d d d d d d d d o d d d d p d d d d d
# d d d d d o d d O O d d d . m d d d d d
# d d d d d o d d d d d d d d d d d d d d
# d d d d d O O d d . d d d d d d d d d d
# d d d d d d d d d m d d d d d d d d d d
#
# Day: 7 Time: Night (Tick: 188)
# Entities: 1643 (Plants: 1632, Pauvres: 6, Malheureux: 5)
# d d d d d d d d O O o d d d d d d d d d
# d d d d d d d O O d d d d d d d d d d d
# d d d d d d p o d d d d d d d d O d d d
# d d d d d . d p d d d d d d d d d d d d
# d d d d d d d d d d d d d d d d o d d d
# d d d d d d d d d d d d d d d d o d d d
# d d d d d d d d d d d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
# d d o d O d d d d d d d d d d d d d d d
# d . p d d d p . d d d d d d o O O d d d
# d d d o O O d d m . d d d d O O o d d d
# d d d d d d d d d d d d d O o d o d O d
# d d d d d O p d d d d d d d d d o O d d
# d d d d d m d d P d d d d d d d d d d d
# d d d d d d O d o d m d d d d d d d d d
# d d d d d d o o d O o d d d p d d d d d
# d d d d d O d d O O o d d . m d d d d d
# d d d d d O d d d d d d d d d d d d d d
# d d d d d O O d d . d d d d d d d d d d
# d d d d d d o d d m d d d d d d d d d d
#
# Day: 7 Time: Night (Tick: 189)
# Entities: 1643 (Plants: 1632, Pauvres: 6, Malheureux: 5)
# d d d d d d d d O O O d d d d d d d d d
# d d d d d o d O O o d d d d d d d d d d
# d d d d d d p O o d d d d d d d O o d d
# d d d d d . d p d d d d d d d d o o d d
# d d d d d d d d d d d d d d d d O d d d
# d d d d d d d d d d d d d d d d O o d d
# d d d d d d d d d d d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
# d d O d O d d d d d d d d d d o d d d d
# d . p d d d p . d d d d d d O O O d d d
# d d d O O O d d m . d d o d O O O o d d
# d d d o d o o d d d d d d O O o O d O d
# d d d o d O p d d d d d d o o d O O d d
# d d d o d m o d P d d d d d d d o d o d
# d d d d d d O d O d m o d d d d d d d d
# d d d d d o O O d O O d d d p d d d d d
# d d d d d O d d O O O o d . m d d d d d
# d d d d d O d o d d d d d d d d d d d d
# d d d d d O O o d . d d d d d d d d d d
# d d d d o d O o d m d d d d d d d d d d
#
# Day: 7 Time: Night (Tick: 190)
# Entities: 1643 (Plants: 1632, Pauvres: 6, Malheureux: 5)
# d d d d d o d o O O O d d d d d d d d d
# d d d d d O o O O O d d d d d d d o d d
# d d d d d d p O O d o d d d d o O O d d
# d d d d d . d p d o d d d d d d O O d d
# d d d d d d d d d d d d d d d d O d o d
# d d d d d d d d d d d d d d d d O O d d
# d d d d d d d d d d d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
# d d O d O d d d d d d d d d d O d d d d
# d . p d o o p . d d d d d d O O O d d d
# d d o O O O d d m . d d O d O O O O d d
# d d d O o O O d d d d d d O O O O o O d
# d d d O d O p d d d d o d O O d O O d d
# d d d O d m O d P d d o d o d d O d O d
# d d d d d o O o O d m O d d d d d d d d
# d d d d o O O O o O O d d d p d d d d d
# d d d d d O d d O O O O d . m d d d d d
# d d d d d O o O o d d d d d d d d d d d
# d d d d d O O o d . d d d d d d d d d d
# d d d d O o O O d m d d d d d d d d d d
#
# Day: 7 Time: Night (Tick: 191)
# Entities: 1644 (Plants: 1633, Pauvres: 6, Malheureux: 5)
# d d d d d O d O O O O d d d d d d d d d
# d d d d d O O O O O o o d d d d o O d d
# d d d d d d p O O d O d d d d O O O o d
# d d d d d . d p d O d d d d d o O O o d
# d d d d d d d d d d d d d d d d O o O d
# d d d d d d d d d d d d d d d d O O o d
# d d d d d d d d d d d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
# d d O o O d d d d d d d d d d O o d d d
# d o p d O O p . d d d d d d O O O d d d
# d d O O O O d d m . d d O d O O O O o d
# d d d O o O O d d d d d d O O O O O O d
# d d o O o O p d d d d O d O O o O O d d
# d d d O o m O d P d d O d O d d O d O d
# d d d d d O O O O o m O o d d d d d d d
# d d d d O O O O o O O o o d p d d d d d
# d d d d o O o o O O O O o . m d d d d d
# d d d d o O o O O d d d o d d d d d d d
# d d d d o O O O d . d d d d d d d d d d
# d d d d O O O O d m d d d d d d d d d d
#
# Day: 8 Time: Morning (Tick: 192)
# Entities: 1644 (Plants: 1634, Pauvres: 5, Malheureux: 5)
# D D D D d o d o o o o d d d D D D D D D
# D D D d d o o o o o d d d d d d d o D D
# D D D D d d P o o d o d d d d o o o o D
# D D D D d d d . d o d d d d d d o o d D
# D D D D d d P d d d d d d d d d o d o D
# D D D d D d d d d d d d d D d d o o o d
# D D D d d d d d d d d d d d D d d d d D
# D D D d d d d d d d d d d d d d d d d D
# D D o d o d d d d d d d d d d o d d d d
# D o . d o P . d . d d d d d o o o d d d
# D d o P o o d d . M d d o d o o o o d d
# D D d o . o o d d d d d d o o o o o o d
# D d d o d M P d d d d o d o o d o o d D
# D D d o d . o d P d d o d o d d o d o D
# D d d d d o o o o . . o d . d d d d d d
# D D d d o o o o d o M d d d M d d D d D
# D D D d d o d d o o o o d d . d d d D D
# D D D D d o d o o d d d d d d d d d d D
# D D D D d o o o . d d d d d d d d d d d
# D D D D o o o o d M d d d d D D D D d D
#
# Day: 8 Time: Morning (Tick: 193)
# Entities: 1656 (Plants: 1646, Pauvres: 5, Malheureux: 5)
# D D D D D o d o d d o d d d D D D D D D
# D D D d D d d d d d d d d d d d d d D D
# D D D D D d . d d d d d d d d d d d d D
# D D D D d d d P d d d d d d d d d o D D
# D D D D d d . d d d d d d d d d d D o D
# D D D D D d P d d d d d d D d d o o d d
# D D D d d d d d d d d d d d D d d d d D
# D D D d d d d d d d d d d d d d d d d D
# D D d d d d d d d d d d d d d d d d d D
# D d d d d . d d M d d d d d d d d d d d
# D d d . d d P d d . d d d d d d d d d D
# D D d P d d d d d d d d d d d d d d d D
# D d d d d M . d d d d d d d d d d d d D
# D D d d d d d P P d d d d d d d d D d D
# D d d d d d d d d d d d d d d d d d d D
# D D d d d d d d d d . d d d . d d D d D
# D D D d d d d d d d M d d d d M d d D D
# D D D D d d d d d d d d d d d d d d d D
# D D D D d d d d d M d d d d d d d d d d
# D D D D d d d d d . d d D d D D D D D D
#
# Day: 8 Time: Morning (Tick: 194)
# Entities: 1665 (Plants: 1655, Pauvres: 5, Malheureux: 5)
# D D D D D d d d d D d d d d D D D D D D
# D D D D D d d d d d d d d d d d d d D D
# D D D D D D d d d d d d d d d d d d d D
# D D D D d d d P d d d d d d d d d o D D
# D D D D d d d P d d d d d d d d d D d D
# D D D D D d . d d d d d d D d d d d D D
# D D D d d d d d d d d d d d D d d d d D
# D D D d d d d d d d d d d d d d d d d D
# D D d d d d d d d d d d d d d d d d d D
# D D d d d d d d M d d d d d d d d d d d
# D d d d P d P d d d d d d d d d D d d D
# D D d . d d d d d d d d d d d d D d d D
# D d d d d M d d d d d d d d d d d d d D
# D D d d d d d P P d d d d d d d d D d D
# D D d d d d d d d d d d d d d d d d d D
# D D d d d d d d d d d d d d d d d D d D
# D D D d d d d d d d M d d d M . d d D D
# D D D D d d d d d d d d d d d d d d d D
# D D D D d d d d d M d d d d d d d d d d
# D D D D D d d d d d d D D d D D D D D D
#
# Day: 8 Time: Morning (Tick: 195)
# Entities: 1668 (Plants: 1658, Pauvres: 5, Malheureux: 5)
# D D D D D d d d d D d d d d D D D D D D
# D D D D D D d d d d d d d d d d d d D D
# D D D D D D d d d d d d d d d d d d d D
# D D D D D D d P d d d d d d d d d d D D
# D D D D d d d P d d d d d d d d d D D D
# D D D D D D d d d d d d d D D d d d D D
# D D D D d d d d d d d d D D D d D d d D
# D D D d d d d d d d d d d d d d d d d D
# D D d d d d d d d d d d d d d d d d d D
# D D d d d d P d M d d d d d d d d d d d
# D d d d . d . d d d d d d d d d D d d D
# D D d d P d d d d d d d d d d d D d d D
# D d d d d . M d d d d d d d d d d d d D
# D D d d d d d P P d d d d d d d d D d D
# D D d d d d d d d d d d d d d d d d d D
# D D d d d d d d d d d d d M d d d D D D
# D D D d d d d d d d M d d d . d d d D D
# D D D D d d d d d d d d d d d d d D d D
# D D D D d d d d d . d d d d d d d d d d
# D D D D D d d d d d M D D d D D D D D D
#
# Day: 8 Time: Morning (Tick: 196)
# Entities: 1673 (Plants: 1663, Pauvres: 5, Malheureux: 5)
# D D D D D d d d d D d d d d D D D D D D
# D D D D D D d d d d d d d d d d d d D D
# D D D D D D d d d d d d d d d d d D d D
# D D D D D D d P d d d d d d d d d d D D
# D D D D d d P . d d d d d d d d d D D D
# D D D D D D d d d d d d d D D d d d D D
# D D D D d d d d d d d d D D D d D d d D
# D D D d d d d d d d d d d d d d d d d D
# D D d d d d d d d M d d d d d d D d d D
# D D d d d d . d . d d d d d d d d d d D
# D d d d d d d P d d d d d d d d D d d D
# D D d d . P d d d d d d d d d d D d d D
# D d d d d d . d d d d d d d d d d d d D
# D D d d d M d P P d d d d d d d d D d D
# D D d d d d d d d d d d d d d d d d d D
# D D d d d d d d d d d d d . d d d D D D
# D D D d d d d d d M . d d M d d d d D D
# D D D D d d d d d d d d d d d d d D d D
# D D D D d d d d d d d d d d d d d d d D
# D D D D D d d d d d M D D d D D D D D D
#
# Day: 8 Time: Morning (Tick: 197)
# Entities: 1680 (Plants: 1670, Pauvres: 5, Malheureux: 5)
# D D D D D d d d d D d d d d D D D D D D
# D D D D D D d d d d d d d d d d d d D D
# D D D D D D d d d d d d d d d d d D d D
# D D D D D D d P d d d d d d d d d d D D
# D D D D d D . d d d d d d d d d D D D D
# D D D D D P d d d d d d d D D D d D D D
# D D D D d d d d d d d d D D D d D d D D
# D D D D d d d d d d d d d D d d d d d D
# D D d D d d d d M . d d d d d d D d d D
# D D d d d d d d d d d d d d d d d d d D
# D d d d d d d . d d d d d d d d D d d D
# D D d d P . P d d d d d d d d d D D D D
# D d d d d M d P d d d d d d d d d d d D
# D D d d d . d . P d d d d d d d d D d D
# D D d d d d d d d d d d d d d d d d d D
# D D d d d d d d d d d d d d M d d D D D
# D D D d d d d d d M d d d . d d d d D D
# D D D D d d d d d d d d d d d d d D D D
# D D D D d d d d d d d d d d d d d d d D
# D D D D D d D d d d . M D d D D D D D D
#
# Day: 8 Time: Day (Tick: 198)
# Entities: 1681 (Plants: 1671, Pauvres: 5, Malheureux: 5)
# d d d d d d d d d d d d d d d d d d d d
# d d d d d d d . l d d d d d d d d d d d
# d d d d d d P l d d d d d d d d d d d d
# d d d d d d d . d d d d d d d d d d d d
# d d d d d d . d d d d d d d d d d d d d
# d d d d d . P d d d d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
# d d d d d d d d m . d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
# d d d d d P d . d d l d d d d d d d d d
# d d d d . P . d d d d l d d d d d d d d
# d d d d d m d P d d l d d d d d d l d d
# d d d d d . d . P d d l l l d d l d d d
# d d d d d d d d l l d d l l l d d d d d
# d d d d d d d d d l d l d l m d l d d d
# d d d d d d d d d m d d l l l l d d d d
# d d d d d d d d d d d d l l d l d d d d
# d d d d d d d d l l d d d d d d d d d d
# d d d d d d d d d d l m d l d d d d d d
#
# Day: 8 Time: Day (Tick: 199)
# Entities: 1681 (Plants: 1671, Pauvres: 5, Malheureux: 5)
# d d d d d d . d l d d d d d d d d d d d
# d d d d d P l l L l d d d d d d d l d d
# d d d d d d . L d l d d d d d d d d d d
# d d d d d d d . d d l d d d d d d d d d
# d d d d d d P d d d d d d d d d d d d d
# d d d d d . . d d d d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
# d d d d d d d d m . d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
# d d d d d P d . d d L d d d d d d d d d
# d d d d . . P d d d d L d d d d d d d d
# d d d d d m d P d d L d l l d l d L d d
# d d d d d . d . P l l l l l l l L d d d
# d d d d d d d l L L l l l l l l d d d d
# d d d d d d d d d L l l l l m l L d d d
# d d d d d d d d d m l l l l l l d l d d
# d d d d d d d d l l l l L l l L d d d d
# d d d d d d d d L L d l l l l d d d d d
# d d d d d d d d d d L m d L d d d d d d
#
# Day: 8 Time: Day (Tick: 200)
# Entities: 1680 (Plants: 1670, Pauvres: 5, Malheureux: 5)
# d d d d d d . l l l d d d d d d d d d d
# d d d d d P . L L L d d d d d d l L d d
# d d d d d d . L d l d d d d d d d l d d
# d d d d d d . l d l L d d d d d d d d d
# d d d d d d P d d d d d d d d d d d d d
# d d d d d . . d d d d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
# d d d d d d d d m . d d d d d d d d d d
# d d d d d d d d d d d d d d d d d d d d
# d d d d P . d . d d L l d d d d d d d d
# d d d d . P P d d d l L d d d l d l d d
# d d d d d m d . d l L l L L l L d L l d
# d d d d d . d . P L l l L l l l L d l d
# d d d d d d d L L L l l l l l l d d d d
# d d d d d d d d d L l l l l m l L d d d
# d d d d d d d d d m l l L l l l l L d d
# d d d d d d d d L l l l L l L L d d d d
# d d d d d d d d L L l l l L L l d d d d
# d d d d d d d d d d L m d L d d d d d d
#
# Simulation finished.
# Final stats: Day 8, Total entities: 1680
# Plants: 1670
# Pauvres: 5
# Malheureux: 5
